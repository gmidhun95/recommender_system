# %%
from imdb import IMDb
import time
import json
ia = IMDb()
ids = []
c = 0
for l in open('./recommender_system/project_part1/movielens_small/links.csv').readlines()[1:]:
    x = l.strip().split(',')[1]
    ids.append(x)
    temp = ia.get_movie(x)
    for l in temp.iteritems():
        print l[0],l[1]
    c+=1
    print temp.__class__
    print c, time.time()
    break
# Out:
# music department [<Person id:0178423[http] name:_Cooper, Tod_>, <Person id:0204485[http] name:_Davis, Don_>, <Person id:0214010[http] name:_DeCrescent, Sandy_>, <Person id:0219337[http] name:_Dennen, Greg_>, <Person id:0280963[http] name:_Flamberg, James_>, <Person id:0362436[http] name:_Hardisty, Tom_>, <Person id:0455906[http] name:_Kinsley, Bill_>, <Person id:0494758[http] name:_Lea, Helena_>, <Person id:0508467[http] name:_Li, Ling Ling_>, <Person id:0572660[http] name:_McLean, Susan_>, <Person id:0598895[http] name:_Montan, Chris_>, <Person id:0005271[http] name:_Newman, Randy_>, <Person id:0709841[http] name:_Randles, Robert_>, <Person id:0737428[http] name:_Rogut, Rail_>, <Person id:0937745[http] name:_Wolf, Frank_>, <Person id:0937745[http] name:_Wolf, Frank_>, <Person id:0008856[http] name:_Abondolo, Nico_>, <Person id:1784190[http] name:_Ahn, Eun-Mee_>, <Person id:2810953[http] name:_Altenbach, Richard_>, <Person id:0026550[http] name:_Anderson, Dale_>, <Person id:0043868[h
# ...
