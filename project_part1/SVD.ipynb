# %%
import pandas as pd
import pickle
import random
from surprise import prediction_algorithms as pa
from surprise import Dataset, Reader, GridSearch, accuracy, dump
from surprise import evaluate, print_perf
from sklearn.model_selection import train_test_split
import time

# %%
data = pd.read_csv('./ml-100k/data.csv')
df = pd.DataFrame(data)
df.drop('timestamp', axis=1, inplace=True)
reader = Reader(rating_scale=(1, 5))
dataset = Dataset.load_from_df(df[['userId', 'movieId', 'rating']], reader)
raw_ratings = dataset.raw_ratings
random.shuffle(raw_ratings)
threshold = int(.8 * len(raw_ratings))
A_raw_ratings = raw_ratings[:threshold]
B_raw_ratings = raw_ratings[threshold:]
dataset.raw_ratings = A_raw_ratings
dataset.split(n_folds=5)

# %%
latent_factors = [30,40,50,60,70,80,90,100,110,120]
regularizations = [0.5,0.2,0.1,0.05,0.02,0.01]
start_time = int(time.time())
param_grid = {'n_factors': latent_factors, 'n_epochs': [100], 'biased': [False], 'reg_all': regularizations}
grid_search = GridSearch(pa.matrix_factorization.SVD, param_grid=param_grid, measures=['MAE', 'RMSE', 'FCP'])
grid_search.evaluate(dataset)
end_time = int(time.time())
print (start_time-end_time)/(len(latent_factors)*len(regularizations))
pickle.dump(grid_search.cv_results, open("svd_result1","wb"))
# Out:
# [{'reg_all': 0.5, 'n_factors': 30, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.5, 'n_factors': 40, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.5, 'n_factors': 50, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.5, 'n_factors': 60, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.5, 'n_factors': 70, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.5, 'n_factors': 80, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.5, 'n_factors': 90, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.5, 'n_factors': 100, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.5, 'n_factors': 110, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.5, 'n_factors': 120, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.2, 'n_factors': 30, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.2, 'n_factors': 40, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.2, 'n_factors': 50, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.2, 'n_factors': 60, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.2, 'n_factors': 70, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.2, 'n_factors': 80, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.2, 'n_factors': 90, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.2, 'n_factors': 100, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.2, 'n_factors': 110, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.2, 'n_factors': 120, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 30, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 40, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 50, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 60, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 70, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 80, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 90, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 100, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 110, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 120, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.05, 'n_factors': 30, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.05, 'n_factors': 40, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.05, 'n_factors': 50, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.05, 'n_factors': 60, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.05, 'n_factors': 70, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.05, 'n_factors': 80, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.05, 'n_factors': 90, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.05, 'n_factors': 100, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.05, 'n_factors': 110, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.05, 'n_factors': 120, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.02, 'n_factors': 30, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.02, 'n_factors': 40, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.02, 'n_factors': 50, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.02, 'n_factors': 60, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.02, 'n_factors': 70, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.02, 'n_factors': 80, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.02, 'n_factors': 90, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.02, 'n_factors': 100, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.02, 'n_factors': 110, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.02, 'n_factors': 120, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.01, 'n_factors': 30, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.01, 'n_factors': 40, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.01, 'n_factors': 50, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.01, 'n_factors': 60, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.01, 'n_factors': 70, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.01, 'n_factors': 80, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.01, 'n_factors': 90, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.01, 'n_fac ...
# ------------
# Parameters combination 1 of 60
# params:  {'reg_all': 0.5, 'n_factors': 30, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8866
# Mean RMSE: 1.0746
# Mean FCP : 0.6864
# ------------
# ------------
# Parameters combination 2 of 60
# params:  {'reg_all': 0.5, 'n_factors': 40, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8866
# Mean RMSE: 1.0746
# Mean FCP : 0.6864
# ------------
# ------------
# Parameters combination 3 of 60
# params:  {'reg_all': 0.5, 'n_factors': 50, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8866
# Mean RMSE: 1.0746
# Mean FCP : 0.6864
# ------------
# ------------
# Parameters combination 4 of 60
# params:  {'reg_all': 0.5, 'n_factors': 60, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8867
# Mean RMSE: 1.0746
# Mean FCP : 0.6864
# ------------
# ------------
# Parameters combination 5 of 60
# params:  {'reg_all': 0.5, 'n_factors': 70, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8867
# Mean RMSE: 1.0746
# Mean FCP : 0.6864
# ------------
# ------------
# Parameters combination 6 of 60
# params:  {'reg_all': 0.5, 'n_factors': 80, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8867
# Mean RMSE: 1.0747
# Mean FCP : 0.6864
# ------------
# ------------
# Parameters combination 7 of 60
# params:  {'reg_all': 0.5, 'n_factors': 90, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8867
# Mean RMSE: 1.0746
# Mean FCP : 0.6864
# ------------
# ------------
# Parameters combination 8 of 60
# params:  {'reg_all': 0.5, 'n_factors': 100, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8867
# Mean RMSE: 1.0747
# Mean FCP : 0.6864
# ------------
# ------------
# Parameters combination 9 of 60
# params:  {'reg_all': 0.5, 'n_factors': 110, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8867
# Mean RMSE: 1.0747
# Mean FCP : 0.6864
# ------------
# ------------
# Parameters combination 10 of 60
# params:  {'reg_all': 0.5, 'n_factors': 120, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8867
# Mean RMSE: 1.0747
# Mean FCP : 0.6864
# ------------
# ------------
# Parameters combination 11 of 60
# params:  {'reg_all': 0.2, 'n_factors': 30, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7644
# Mean RMSE: 0.9521
# Mean FCP : 0.7064
# ------------
# ------------
# Parameters combination 12 of 60
# params:  {'reg_all': 0.2, 'n_factors': 40, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7638
# Mean RMSE: 0.9514
# Mean FCP : 0.7071
# ------------
# ------------
# Parameters combination 13 of 60
# params:  {'reg_all': 0.2, 'n_factors': 50, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7640
# Mean RMSE: 0.9516
# Mean FCP : 0.7071
# ------------
# ------------
# Parameters combination 14 of 60
# params:  {'reg_all': 0.2, 'n_factors': 60, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7636
# Mean RMSE: 0.9513
# Mean FCP : 0.7076
# ------------
# ------------
# Parameters combination 15 of 60
# params:  {'reg_all': 0.2, 'n_factors': 70, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7636
# Mean RMSE: 0.9511
# Mean FCP : 0.7076
# ------------
# ------------
# Parameters combination 16 of 60
# params:  {'reg_all': 0.2, 'n_factors': 80, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7635
# Mean RMSE: 0.9511
# Mean FCP : 0.7078
# ------------
# ------------
# Parameters combination 17 of 60
# params:  {'reg_all': 0.2, 'n_factors': 90, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7636
# Mean RMSE: 0.9514
# Mean FCP : 0.7077
# ------------
# ------------
# Parameters combination 18 of 60
# params:  {'reg_all': 0.2, 'n_factors': 100, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7634
# Mean RMSE: 0.9510
# Mean FCP : 0.7087
# ------------
# ------------
# Parameters combination 19 of 60
# params:  {'reg_all': 0.2, 'n_factors': 110, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7635
# Mean RMSE: 0.9512
# Mean FCP : 0.7084
# ------------
# ------------
# Parameters combination 20 of 60
# params:  {'reg_all': 0.2, 'n_factors': 120, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7634
# Mean RMSE: 0.9510
# Mean FCP : 0.7084
# ------------
# ------------
# Parameters combination 21 of 60
# params:  {'reg_all': 0.1, 'n_factors': 30, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7364
# Mean RMSE: 0.9297
# Mean FCP : 0.7137
# ------------
# ------------
# Parameters combination 22 of 60
# params:  {'reg_all': 0.1, 'n_factors': 40, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7385
# Mean RMSE: 0.9322
# Mean FCP : 0.7139
# ------------
# ------------
# Parameters combination 23 of 60
# params:  {'reg_all': 0.1, 'n_factors': 50, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7377
# Mean RMSE: 0.9305
# Mean FCP : 0.7151
# ------------
# ------------
# Parameters combination 24 of 60
# params:  {'reg_all': 0.1, 'n_factors': 60, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7374
# Mean RMSE: 0.9306
# Mean FCP : 0.7163
# ------------
# ------------
# Parameters combination 25 of 60
# params:  {'reg_all': 0.1, 'n_factors': 70, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7382
# Mean RMSE: 0.9308
# Mean FCP : 0.7158
# ------------
# ------------
# Parameters combination 26 of 60
# params:  {'reg_all': 0.1, 'n_factors': 80, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7382
# Mean RMSE: 0.9316
# Mean FCP : 0.7155
# ------------
# ------------
# Parameters combination 27 of 60
# params:  {'reg_all': 0.1, 'n_factors': 90, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7388
# Mean RMSE: 0.9313
# Mean FCP : 0.7159
# ------------
# ------------
# Parameters combination 28 of 60
# params:  {'reg_all': 0.1, 'n_factors': 100, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7389
# Mean RMSE: 0.9314
# Mean FCP : 0.7165
# ------------
# ------------
# Parameters combination 29 of 60
# params:  {'reg_all': 0.1, 'n_factors': 110, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7401
# Mean RMSE: 0.9327
# Mean FCP : 0.7142
# ------------
# ------------
# Parameters combination 30 of 60
# params:  {'reg_all': 0.1, 'n_factors': 120, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7401
# Mean RMSE: 0.9324
# Mean FCP : 0.7164
# ------------
# ------------
# Parameters combination 31 of 60
# params:  {'reg_all': 0.05, 'n_factors': 30, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7616
# Mean RMSE: 0.9711
# Mean FCP : 0.6931
# ------------
# ------------
# Parameters combination 32 of 60
# params:  {'reg_all': 0.05, 'n_factors': 40, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7612
# Mean RMSE: 0.9707
# Mean FCP : 0.6917
# ------------
# ------------
# Parameters combination 33 of 60
# params:  {'reg_all': 0.05, 'n_factors': 50, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7594
# Mean RMSE: 0.9660
# Mean FCP : 0.6963
# ------------
# ------------
# Parameters combination 34 of 60
# params:  {'reg_all': 0.05, 'n_factors': 60, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7585
# Mean RMSE: 0.9632
# Mean FCP : 0.6972
# ------------
# ------------
# Parameters combination 35 of 60
# params:  {'reg_all': 0.05, 'n_factors': 70, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7577
# Mean RMSE: 0.9620
# Mean FCP : 0.6986
# ------------
# ------------
# Parameters combination 36 of 60
# params:  {'reg_all': 0.05, 'n_factors': 80, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7562
# Mean RMSE: 0.9596
# Mean FCP : 0.6984
# ------------
# ------------
# Parameters combination 37 of 60
# params:  {'reg_all': 0.05, 'n_factors': 90, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7552
# Mean RMSE: 0.9573
# Mean FCP : 0.7015
# ------------
# ------------
# Parameters combination 38 of 60
# params:  {'reg_all': 0.05, 'n_factors': 100, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7537
# Mean RMSE: 0.9559
# Mean FCP : 0.7015
# ------------
# ------------
# Parameters combination 39 of 60
# params:  {'reg_all': 0.05, 'n_factors': 110, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7547
# Mean RMSE: 0.9566
# Mean FCP : 0.7034
# ------------
# ------------
# Parameters combination 40 of 60
# params:  {'reg_all': 0.05, 'n_factors': 120, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7523
# Mean RMSE: 0.9525
# Mean FCP : 0.7050
# ------------
# ------------
# Parameters combination 41 of 60
# params:  {'reg_all': 0.02, 'n_factors': 30, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8094
# Mean RMSE: 1.0417
# Mean FCP : 0.6648
# ------------
# ------------
# Parameters combination 42 of 60
# params:  {'reg_all': 0.02, 'n_factors': 40, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8122
# Mean RMSE: 1.0404
# Mean FCP : 0.6646
# ------------
# ------------
# Parameters combination 43 of 60
# params:  {'reg_all': 0.02, 'n_factors': 50, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8054
# Mean RMSE: 1.0307
# Mean FCP : 0.6680
# ------------
# ------------
# Parameters combination 44 of 60
# params:  {'reg_all': 0.02, 'n_factors': 60, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8046
# Mean RMSE: 1.0263
# Mean FCP : 0.6686
# ------------
# ------------
# Parameters combination 45 of 60
# params:  {'reg_all': 0.02, 'n_factors': 70, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8001
# Mean RMSE: 1.0190
# Mean FCP : 0.6690
# ------------
# ------------
# Parameters combination 46 of 60
# params:  {'reg_all': 0.02, 'n_factors': 80, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7964
# Mean RMSE: 1.0147
# Mean FCP : 0.6735
# ------------
# ------------
# Parameters combination 47 of 60
# params:  {'reg_all': 0.02, 'n_factors': 90, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7909
# Mean RMSE: 1.0061
# Mean FCP : 0.6777
# ------------
# ------------
# Parameters combination 48 of 60
# params:  {'reg_all': 0.02, 'n_factors': 100, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7893
# Mean RMSE: 1.0029
# Mean FCP : 0.6801
# ------------
# ------------
# Parameters combination 49 of 60
# params:  {'reg_all': 0.02, 'n_factors': 110, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7875
# Mean RMSE: 0.9998
# Mean FCP : 0.6816
# ------------
# ------------
# Parameters combination 50 of 60
# params:  {'reg_all': 0.02, 'n_factors': 120, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7858
# Mean RMSE: 0.9970
# Mean FCP : 0.6804
# ------------
# ------------
# Parameters combination 51 of 60
# params:  {'reg_all': 0.01, 'n_factors': 30, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8344
# Mean RMSE: 1.0777
# Mean FCP : 0.6558
# ------------
# ------------
# Parameters combination 52 of 60
# params:  {'reg_all': 0.01, 'n_factors': 40, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8419
# Mean RMSE: 1.0830
# Mean FCP : 0.6462
# ------------
# ------------
# Parameters combination 53 of 60
# params:  {'reg_all': 0.01, 'n_factors': 50, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8373
# Mean RMSE: 1.0752
# Mean FCP : 0.6542
# ------------
# ------------
# Parameters combination 54 of 60
# params:  {'reg_all': 0.01, 'n_factors': 60, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8367
# Mean RMSE: 1.0702
# Mean FCP : 0.6546
# ------------
# ------------
# Parameters combination 55 of 60
# params:  {'reg_all': 0.01, 'n_factors': 70, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8309
# Mean RMSE: 1.0604
# Mean FCP : 0.6529
# ------------
# ------------
# Parameters combination 56 of 60
# params:  {'reg_all': 0.01, 'n_factors': 80, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8252
# Mean RMSE: 1.0513
# Mean FCP : 0.6582
# ------------
# ------------
# Parameters combination 57 of 60
# params:  {'reg_all': 0.01, 'n_factors': 90, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8202
# Mean RMSE: 1.0443
# Mean FCP : 0.6616
# ------------
# ------------
# Parameters combination 58 of 60
# params:  {'reg_all': 0.01, 'n_factors': 100, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8166
# Mean RMSE: 1.0390
# Mean FCP : 0.6628
# ------------
# ------------
# Parameters combination 59 of 60
# params:  {'reg_all': 0.01, 'n_factors': 110, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8146
# Mean RMSE: 1.0355
# Mean FCP : 0.6646
# ------------
# ------------
# Parameters combination 60 of 60
# params:  {'reg_all': 0.01, 'n_factors': 120, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8105
# Mean RMSE: 1.0282
# Mean FCP : 0.6701
# ------------
# -57

# %%
best_score = grid_search.best_score["RMSE"]
best_params = grid_search.best_params["RMSE"]
print best_score,best_params
# Out:
# 0.929726850058 {'reg_all': 0.1, 'n_factors': 30, 'biased': False, 'n_epochs': 100}

# %% [markdown]
# the best solutin is obtained to regularization of 0.1 and for finding the optimal number of epochs and latent_factor vary number of factors from 20 to 100 in length of 10 and number of epoch fr

# %%
latent_factors = [20,30,40,50,60,70,80,90,100]
epochs = [20,50,100]
start_time = int(time.time())
param_grid = {'n_factors': latent_factors, 'n_epochs': epochs, 'biased': [False], 'reg_all': [0.1]}
grid_search = GridSearch(pa.matrix_factorization.SVD, param_grid=param_grid, measures=['MAE', 'RMSE', 'FCP'])
grid_search.evaluate(dataset)
end_time = int(time.time())
print (start_time-end_time)/(len(latent_factors)*len(epochs))
pickle.dump(grid_search.cv_results, open("svd_result2","wb"))
# Out:
# [{'reg_all': 0.1, 'n_factors': 20, 'biased': False, 'n_epochs': 20}, {'reg_all': 0.1, 'n_factors': 20, 'biased': False, 'n_epochs': 50}, {'reg_all': 0.1, 'n_factors': 20, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 30, 'biased': False, 'n_epochs': 20}, {'reg_all': 0.1, 'n_factors': 30, 'biased': False, 'n_epochs': 50}, {'reg_all': 0.1, 'n_factors': 30, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 40, 'biased': False, 'n_epochs': 20}, {'reg_all': 0.1, 'n_factors': 40, 'biased': False, 'n_epochs': 50}, {'reg_all': 0.1, 'n_factors': 40, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 50, 'biased': False, 'n_epochs': 20}, {'reg_all': 0.1, 'n_factors': 50, 'biased': False, 'n_epochs': 50}, {'reg_all': 0.1, 'n_factors': 50, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 60, 'biased': False, 'n_epochs': 20}, {'reg_all': 0.1, 'n_factors': 60, 'biased': False, 'n_epochs': 50}, {'reg_all': 0.1, 'n_factors': 60, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 70, 'biased': False, 'n_epochs': 20}, {'reg_all': 0.1, 'n_factors': 70, 'biased': False, 'n_epochs': 50}, {'reg_all': 0.1, 'n_factors': 70, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 80, 'biased': False, 'n_epochs': 20}, {'reg_all': 0.1, 'n_factors': 80, 'biased': False, 'n_epochs': 50}, {'reg_all': 0.1, 'n_factors': 80, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 90, 'biased': False, 'n_epochs': 20}, {'reg_all': 0.1, 'n_factors': 90, 'biased': False, 'n_epochs': 50}, {'reg_all': 0.1, 'n_factors': 90, 'biased': False, 'n_epochs': 100}, {'reg_all': 0.1, 'n_factors': 100, 'biased': False, 'n_epochs': 20}, {'reg_all': 0.1, 'n_factors': 100, 'biased': False, 'n_epochs': 50}, {'reg_all': 0.1, 'n_factors': 100, 'biased': False, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 27
# params:  {'reg_all': 0.1, 'n_factors': 20, 'biased': False, 'n_epochs': 20}
# ------------
# Mean MAE : 0.7648
# Mean RMSE: 0.9657
# Mean FCP : 0.6977
# ------------
# ------------
# Parameters combination 2 of 27
# params:  {'reg_all': 0.1, 'n_factors': 20, 'biased': False, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7405
# Mean RMSE: 0.9334
# Mean FCP : 0.7117
# ------------
# ------------
# Parameters combination 3 of 27
# params:  {'reg_all': 0.1, 'n_factors': 20, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7367
# Mean RMSE: 0.9317
# Mean FCP : 0.7121
# ------------
# ------------
# Parameters combination 4 of 27
# params:  {'reg_all': 0.1, 'n_factors': 30, 'biased': False, 'n_epochs': 20}
# ------------
# Mean MAE : 0.7638
# Mean RMSE: 0.9644
# Mean FCP : 0.6992
# ------------
# ------------
# Parameters combination 5 of 27
# params:  {'reg_all': 0.1, 'n_factors': 30, 'biased': False, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7398
# Mean RMSE: 0.9328
# Mean FCP : 0.7115
# ------------
# ------------
# Parameters combination 6 of 27
# params:  {'reg_all': 0.1, 'n_factors': 30, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7372
# Mean RMSE: 0.9314
# Mean FCP : 0.7110
# ------------
# ------------
# Parameters combination 7 of 27
# params:  {'reg_all': 0.1, 'n_factors': 40, 'biased': False, 'n_epochs': 20}
# ------------
# Mean MAE : 0.7632
# Mean RMSE: 0.9636
# Mean FCP : 0.7007
# ------------
# ------------
# Parameters combination 8 of 27
# params:  {'reg_all': 0.1, 'n_factors': 40, 'biased': False, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7397
# Mean RMSE: 0.9328
# Mean FCP : 0.7139
# ------------
# ------------
# Parameters combination 9 of 27
# params:  {'reg_all': 0.1, 'n_factors': 40, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7374
# Mean RMSE: 0.9313
# Mean FCP : 0.7140
# ------------
# ------------
# Parameters combination 10 of 27
# params:  {'reg_all': 0.1, 'n_factors': 50, 'biased': False, 'n_epochs': 20}
# ------------
# Mean MAE : 0.7628
# Mean RMSE: 0.9631
# Mean FCP : 0.7009
# ------------
# ------------
# Parameters combination 11 of 27
# params:  {'reg_all': 0.1, 'n_factors': 50, 'biased': False, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7399
# Mean RMSE: 0.9326
# Mean FCP : 0.7145
# ------------
# ------------
# Parameters combination 12 of 27
# params:  {'reg_all': 0.1, 'n_factors': 50, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7382
# Mean RMSE: 0.9313
# Mean FCP : 0.7144
# ------------
# ------------
# Parameters combination 13 of 27
# params:  {'reg_all': 0.1, 'n_factors': 60, 'biased': False, 'n_epochs': 20}
# ------------
# Mean MAE : 0.7631
# Mean RMSE: 0.9632
# Mean FCP : 0.7023
# ------------
# ------------
# Parameters combination 14 of 27
# params:  {'reg_all': 0.1, 'n_factors': 60, 'biased': False, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7405
# Mean RMSE: 0.9337
# Mean FCP : 0.7145
# ------------
# ------------
# Parameters combination 15 of 27
# params:  {'reg_all': 0.1, 'n_factors': 60, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7379
# Mean RMSE: 0.9309
# Mean FCP : 0.7151
# ------------
# ------------
# Parameters combination 16 of 27
# params:  {'reg_all': 0.1, 'n_factors': 70, 'biased': False, 'n_epochs': 20}
# ------------
# Mean MAE : 0.7632
# Mean RMSE: 0.9639
# Mean FCP : 0.7022
# ------------
# ------------
# Parameters combination 17 of 27
# params:  {'reg_all': 0.1, 'n_factors': 70, 'biased': False, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7398
# Mean RMSE: 0.9325
# Mean FCP : 0.7156
# ------------
# ------------
# Parameters combination 18 of 27
# params:  {'reg_all': 0.1, 'n_factors': 70, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7382
# Mean RMSE: 0.9311
# Mean FCP : 0.7148
# ------------
# ------------
# Parameters combination 19 of 27
# params:  {'reg_all': 0.1, 'n_factors': 80, 'biased': False, 'n_epochs': 20}
# ------------
# Mean MAE : 0.7635
# Mean RMSE: 0.9638
# Mean FCP : 0.7033
# ------------
# ------------
# Parameters combination 20 of 27
# params:  {'reg_all': 0.1, 'n_factors': 80, 'biased': False, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7405
# Mean RMSE: 0.9333
# Mean FCP : 0.7156
# ------------
# ------------
# Parameters combination 21 of 27
# params:  {'reg_all': 0.1, 'n_factors': 80, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7382
# Mean RMSE: 0.9310
# Mean FCP : 0.7155
# ------------
# ------------
# Parameters combination 22 of 27
# params:  {'reg_all': 0.1, 'n_factors': 90, 'biased': False, 'n_epochs': 20}
# ------------
# Mean MAE : 0.7643
# Mean RMSE: 0.9642
# Mean FCP : 0.7032
# ------------
# ------------
# Parameters combination 23 of 27
# params:  {'reg_all': 0.1, 'n_factors': 90, 'biased': False, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7411
# Mean RMSE: 0.9341
# Mean FCP : 0.7156
# ------------
# ------------
# Parameters combination 24 of 27
# params:  {'reg_all': 0.1, 'n_factors': 90, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7383
# Mean RMSE: 0.9312
# Mean FCP : 0.7160
# ------------
# ------------
# Parameters combination 25 of 27
# params:  {'reg_all': 0.1, 'n_factors': 100, 'biased': False, 'n_epochs': 20}
# ------------
# Mean MAE : 0.7636
# Mean RMSE: 0.9636
# Mean FCP : 0.7056
# ------------
# ------------
# Parameters combination 26 of 27
# params:  {'reg_all': 0.1, 'n_factors': 100, 'biased': False, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7411
# Mean RMSE: 0.9339
# Mean FCP : 0.7168
# ------------
# ------------
# Parameters combination 27 of 27
# params:  {'reg_all': 0.1, 'n_factors': 100, 'biased': False, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7396
# Mean RMSE: 0.9324
# Mean FCP : 0.7152
# ------------
# -26

# %%
best_score = grid_search.best_score["RMSE"]
best_params = grid_search.best_params["RMSE"]
print best_score,best_params
# Out:
# 0.930927648183 {'reg_all': 0.1, 'n_factors': 60, 'biased': False, 'n_epochs': 100}

# %% [markdown]
# the improvement in rmse from number of epoch = 50 to 100 is small . so take the optimal epochs as 50. and the number of factors between 40-80

# %%
latent_factors = [40,50,60,70,80]
regularizations = [0.5,0.2,0.1,0.05,0.02]
learning_rates = [0.02,0.01,0.005,0.002]
start_time = int(time.time())
param_grid = {'n_factors': latent_factors, 'n_epochs': [50], 'reg_all': regularizations, 'lr_all': learning_rates}
grid_search = GridSearch(pa.matrix_factorization.SVD, param_grid=param_grid, measures=['MAE', 'RMSE', 'FCP'])
grid_search.evaluate(dataset)
end_time = int(time.time())
print (start_time-end_time)/(len(latent_factors)*len(regularizations))
pickle.dump(grid_search.cv_results, open("svd_result3","wb"))
# Out:
# [{'lr_all': 0.02, 'reg_all': 0.5, 'n_factors': 40, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.5, 'n_factors': 50, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.5, 'n_factors': 60, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.5, 'n_factors': 70, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.5, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.2, 'n_factors': 40, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.2, 'n_factors': 50, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.2, 'n_factors': 60, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.2, 'n_factors': 70, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.2, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.1, 'n_factors': 40, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.1, 'n_factors': 50, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.1, 'n_factors': 60, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.1, 'n_factors': 70, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.05, 'n_factors': 40, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.05, 'n_factors': 50, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.05, 'n_factors': 60, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.05, 'n_factors': 70, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.02, 'n_factors': 40, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.02, 'n_factors': 50, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.02, 'n_factors': 60, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.02, 'n_factors': 70, 'n_epochs': 50}, {'lr_all': 0.02, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.5, 'n_factors': 40, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.5, 'n_factors': 50, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.5, 'n_factors': 60, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.5, 'n_factors': 70, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.5, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.2, 'n_factors': 40, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.2, 'n_factors': 50, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.2, 'n_factors': 60, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.2, 'n_factors': 70, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.2, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.1, 'n_factors': 40, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.1, 'n_factors': 50, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.1, 'n_factors': 60, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.1, 'n_factors': 70, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.05, 'n_factors': 40, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.05, 'n_factors': 50, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.05, 'n_factors': 60, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.05, 'n_factors': 70, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.02, 'n_factors': 40, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.02, 'n_factors': 50, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.02, 'n_factors': 60, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.02, 'n_factors': 70, 'n_epochs': 50}, {'lr_all': 0.01, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.5, 'n_factors': 40, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.5, 'n_factors': 50, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.5, 'n_factors': 60, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.5, 'n_factors': 70, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.5, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.2, 'n_factors': 40, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.2, 'n_factors': 50, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.2, 'n_factors': 60, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.2, 'n_factors': 70, 'n_epochs': 50}, {'lr_all': 0.005, ...
# ------------
# Parameters combination 1 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.5, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7753
# Mean RMSE: 0.9655
# Mean FCP : 0.6870
# ------------
# ------------
# Parameters combination 2 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.5, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7753
# Mean RMSE: 0.9655
# Mean FCP : 0.6870
# ------------
# ------------
# Parameters combination 3 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.5, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7753
# Mean RMSE: 0.9655
# Mean FCP : 0.6870
# ------------
# ------------
# Parameters combination 4 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.5, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7753
# Mean RMSE: 0.9655
# Mean FCP : 0.6870
# ------------
# ------------
# Parameters combination 5 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.5, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7753
# Mean RMSE: 0.9655
# Mean FCP : 0.6870
# ------------
# ------------
# Parameters combination 6 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.2, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7457
# Mean RMSE: 0.9370
# Mean FCP : 0.7008
# ------------
# ------------
# Parameters combination 7 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.2, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7457
# Mean RMSE: 0.9369
# Mean FCP : 0.7007
# ------------
# ------------
# Parameters combination 8 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.2, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7457
# Mean RMSE: 0.9369
# Mean FCP : 0.7010
# ------------
# ------------
# Parameters combination 9 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.2, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7456
# Mean RMSE: 0.9368
# Mean FCP : 0.7010
# ------------
# ------------
# Parameters combination 10 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.2, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7455
# Mean RMSE: 0.9366
# Mean FCP : 0.7009
# ------------
# ------------
# Parameters combination 11 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.1, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7338
# Mean RMSE: 0.9297
# Mean FCP : 0.7058
# ------------
# ------------
# Parameters combination 12 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.1, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7332
# Mean RMSE: 0.9283
# Mean FCP : 0.7076
# ------------
# ------------
# Parameters combination 13 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.1, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7329
# Mean RMSE: 0.9272
# Mean FCP : 0.7080
# ------------
# ------------
# Parameters combination 14 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.1, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7318
# Mean RMSE: 0.9259
# Mean FCP : 0.7100
# ------------
# ------------
# Parameters combination 15 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7320
# Mean RMSE: 0.9261
# Mean FCP : 0.7090
# ------------
# ------------
# Parameters combination 16 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.05, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7655
# Mean RMSE: 0.9759
# Mean FCP : 0.6798
# ------------
# ------------
# Parameters combination 17 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.05, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7611
# Mean RMSE: 0.9681
# Mean FCP : 0.6809
# ------------
# ------------
# Parameters combination 18 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.05, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7563
# Mean RMSE: 0.9613
# Mean FCP : 0.6852
# ------------
# ------------
# Parameters combination 19 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.05, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7529
# Mean RMSE: 0.9565
# Mean FCP : 0.6852
# ------------
# ------------
# Parameters combination 20 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7480
# Mean RMSE: 0.9496
# Mean FCP : 0.6912
# ------------
# ------------
# Parameters combination 21 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.02, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.8283
# Mean RMSE: 1.0624
# Mean FCP : 0.6499
# ------------
# ------------
# Parameters combination 22 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.02, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.8204
# Mean RMSE: 1.0488
# Mean FCP : 0.6494
# ------------
# ------------
# Parameters combination 23 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.02, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.8063
# Mean RMSE: 1.0286
# Mean FCP : 0.6540
# ------------
# ------------
# Parameters combination 24 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.02, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7963
# Mean RMSE: 1.0145
# Mean FCP : 0.6587
# ------------
# ------------
# Parameters combination 25 of 100
# params:  {'lr_all': 0.02, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7883
# Mean RMSE: 1.0036
# Mean FCP : 0.6632
# ------------
# ------------
# Parameters combination 26 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.5, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7734
# Mean RMSE: 0.9630
# Mean FCP : 0.6897
# ------------
# ------------
# Parameters combination 27 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.5, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7734
# Mean RMSE: 0.9630
# Mean FCP : 0.6897
# ------------
# ------------
# Parameters combination 28 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.5, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7734
# Mean RMSE: 0.9630
# Mean FCP : 0.6897
# ------------
# ------------
# Parameters combination 29 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.5, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7734
# Mean RMSE: 0.9630
# Mean FCP : 0.6897
# ------------
# ------------
# Parameters combination 30 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.5, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7734
# Mean RMSE: 0.9630
# Mean FCP : 0.6897
# ------------
# ------------
# Parameters combination 31 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.2, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7498
# Mean RMSE: 0.9419
# Mean FCP : 0.6967
# ------------
# ------------
# Parameters combination 32 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.2, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7487
# Mean RMSE: 0.9407
# Mean FCP : 0.6984
# ------------
# ------------
# Parameters combination 33 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.2, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7483
# Mean RMSE: 0.9401
# Mean FCP : 0.6982
# ------------
# ------------
# Parameters combination 34 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.2, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7482
# Mean RMSE: 0.9400
# Mean FCP : 0.6985
# ------------
# ------------
# Parameters combination 35 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.2, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7479
# Mean RMSE: 0.9396
# Mean FCP : 0.6990
# ------------
# ------------
# Parameters combination 36 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.1, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7294
# Mean RMSE: 0.9232
# Mean FCP : 0.7087
# ------------
# ------------
# Parameters combination 37 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.1, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7296
# Mean RMSE: 0.9228
# Mean FCP : 0.7095
# ------------
# ------------
# Parameters combination 38 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.1, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7297
# Mean RMSE: 0.9232
# Mean FCP : 0.7098
# ------------
# ------------
# Parameters combination 39 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.1, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7290
# Mean RMSE: 0.9220
# Mean FCP : 0.7085
# ------------
# ------------
# Parameters combination 40 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7289
# Mean RMSE: 0.9216
# Mean FCP : 0.7103
# ------------
# ------------
# Parameters combination 41 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.05, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7541
# Mean RMSE: 0.9611
# Mean FCP : 0.6864
# ------------
# ------------
# Parameters combination 42 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.05, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7507
# Mean RMSE: 0.9554
# Mean FCP : 0.6882
# ------------
# ------------
# Parameters combination 43 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.05, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7496
# Mean RMSE: 0.9521
# Mean FCP : 0.6893
# ------------
# ------------
# Parameters combination 44 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.05, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7492
# Mean RMSE: 0.9509
# Mean FCP : 0.6905
# ------------
# ------------
# Parameters combination 45 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7457
# Mean RMSE: 0.9473
# Mean FCP : 0.6896
# ------------
# ------------
# Parameters combination 46 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.02, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.8036
# Mean RMSE: 1.0304
# Mean FCP : 0.6550
# ------------
# ------------
# Parameters combination 47 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.02, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7998
# Mean RMSE: 1.0226
# Mean FCP : 0.6589
# ------------
# ------------
# Parameters combination 48 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.02, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7965
# Mean RMSE: 1.0168
# Mean FCP : 0.6587
# ------------
# ------------
# Parameters combination 49 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.02, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7885
# Mean RMSE: 1.0076
# Mean FCP : 0.6607
# ------------
# ------------
# Parameters combination 50 of 100
# params:  {'lr_all': 0.01, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7871
# Mean RMSE: 1.0028
# Mean FCP : 0.6622
# ------------
# ------------
# Parameters combination 51 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.5, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7729
# Mean RMSE: 0.9623
# Mean FCP : 0.6905
# ------------
# ------------
# Parameters combination 52 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.5, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7729
# Mean RMSE: 0.9623
# Mean FCP : 0.6905
# ------------
# ------------
# Parameters combination 53 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.5, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7729
# Mean RMSE: 0.9623
# Mean FCP : 0.6905
# ------------
# ------------
# Parameters combination 54 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.5, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7729
# Mean RMSE: 0.9623
# Mean FCP : 0.6905
# ------------
# ------------
# Parameters combination 55 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.5, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7729
# Mean RMSE: 0.9623
# Mean FCP : 0.6905
# ------------
# ------------
# Parameters combination 56 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.2, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7538
# Mean RMSE: 0.9469
# Mean FCP : 0.6916
# ------------
# ------------
# Parameters combination 57 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.2, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7536
# Mean RMSE: 0.9466
# Mean FCP : 0.6926
# ------------
# ------------
# Parameters combination 58 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.2, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7535
# Mean RMSE: 0.9465
# Mean FCP : 0.6925
# ------------
# ------------
# Parameters combination 59 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.2, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7533
# Mean RMSE: 0.9463
# Mean FCP : 0.6930
# ------------
# ------------
# Parameters combination 60 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.2, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7532
# Mean RMSE: 0.9461
# Mean FCP : 0.6925
# ------------
# ------------
# Parameters combination 61 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7343
# Mean RMSE: 0.9274
# Mean FCP : 0.7041
# ------------
# ------------
# Parameters combination 62 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7339
# Mean RMSE: 0.9266
# Mean FCP : 0.7068
# ------------
# ------------
# Parameters combination 63 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7334
# Mean RMSE: 0.9263
# Mean FCP : 0.7065
# ------------
# ------------
# Parameters combination 64 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7333
# Mean RMSE: 0.9257
# Mean FCP : 0.7067
# ------------
# ------------
# Parameters combination 65 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7328
# Mean RMSE: 0.9252
# Mean FCP : 0.7080
# ------------
# ------------
# Parameters combination 66 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7390
# Mean RMSE: 0.9384
# Mean FCP : 0.6956
# ------------
# ------------
# Parameters combination 67 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7389
# Mean RMSE: 0.9386
# Mean FCP : 0.6947
# ------------
# ------------
# Parameters combination 68 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7381
# Mean RMSE: 0.9371
# Mean FCP : 0.6955
# ------------
# ------------
# Parameters combination 69 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7377
# Mean RMSE: 0.9366
# Mean FCP : 0.6973
# ------------
# ------------
# Parameters combination 70 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7384
# Mean RMSE: 0.9371
# Mean FCP : 0.6977
# ------------
# ------------
# Parameters combination 71 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7665
# Mean RMSE: 0.9783
# Mean FCP : 0.6722
# ------------
# ------------
# Parameters combination 72 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7693
# Mean RMSE: 0.9807
# Mean FCP : 0.6707
# ------------
# ------------
# Parameters combination 73 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7686
# Mean RMSE: 0.9789
# Mean FCP : 0.6721
# ------------
# ------------
# Parameters combination 74 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7682
# Mean RMSE: 0.9792
# Mean FCP : 0.6702
# ------------
# ------------
# Parameters combination 75 of 100
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7646
# Mean RMSE: 0.9746
# Mean FCP : 0.6730
# ------------
# ------------
# Parameters combination 76 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.5, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7746
# Mean RMSE: 0.9644
# Mean FCP : 0.6892
# ------------
# ------------
# Parameters combination 77 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.5, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7746
# Mean RMSE: 0.9644
# Mean FCP : 0.6892
# ------------
# ------------
# Parameters combination 78 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.5, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7746
# Mean RMSE: 0.9644
# Mean FCP : 0.6896
# ------------
# ------------
# Parameters combination 79 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.5, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7746
# Mean RMSE: 0.9644
# Mean FCP : 0.6896
# ------------
# ------------
# Parameters combination 80 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.5, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7747
# Mean RMSE: 0.9644
# Mean FCP : 0.6894
# ------------
# ------------
# Parameters combination 81 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.2, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7565
# Mean RMSE: 0.9498
# Mean FCP : 0.6895
# ------------
# ------------
# Parameters combination 82 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.2, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7565
# Mean RMSE: 0.9498
# Mean FCP : 0.6894
# ------------
# ------------
# Parameters combination 83 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.2, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7565
# Mean RMSE: 0.9498
# Mean FCP : 0.6898
# ------------
# ------------
# Parameters combination 84 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.2, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7565
# Mean RMSE: 0.9498
# Mean FCP : 0.6894
# ------------
# ------------
# Parameters combination 85 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.2, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7565
# Mean RMSE: 0.9498
# Mean FCP : 0.6893
# ------------
# ------------
# Parameters combination 86 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7500
# Mean RMSE: 0.9450
# Mean FCP : 0.6906
# ------------
# ------------
# Parameters combination 87 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7498
# Mean RMSE: 0.9449
# Mean FCP : 0.6911
# ------------
# ------------
# Parameters combination 88 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7496
# Mean RMSE: 0.9446
# Mean FCP : 0.6915
# ------------
# ------------
# Parameters combination 89 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7492
# Mean RMSE: 0.9442
# Mean FCP : 0.6910
# ------------
# ------------
# Parameters combination 90 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7497
# Mean RMSE: 0.9447
# Mean FCP : 0.6919
# ------------
# ------------
# Parameters combination 91 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7458
# Mean RMSE: 0.9421
# Mean FCP : 0.6910
# ------------
# ------------
# Parameters combination 92 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7459
# Mean RMSE: 0.9423
# Mean FCP : 0.6921
# ------------
# ------------
# Parameters combination 93 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7465
# Mean RMSE: 0.9430
# Mean FCP : 0.6908
# ------------
# ------------
# Parameters combination 94 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7459
# Mean RMSE: 0.9422
# Mean FCP : 0.6917
# ------------
# ------------
# Parameters combination 95 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7456
# Mean RMSE: 0.9419
# Mean FCP : 0.6925
# ------------
# ------------
# Parameters combination 96 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 40, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7456
# Mean RMSE: 0.9437
# Mean FCP : 0.6901
# ------------
# ------------
# Parameters combination 97 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 50, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7463
# Mean RMSE: 0.9445
# Mean FCP : 0.6883
# ------------
# ------------
# Parameters combination 98 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 60, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7452
# Mean RMSE: 0.9437
# Mean FCP : 0.6900
# ------------
# ------------
# Parameters combination 99 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 70, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7462
# Mean RMSE: 0.9449
# Mean FCP : 0.6879
# ------------
# ------------
# Parameters combination 100 of 100
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7483
# Mean RMSE: 0.9471
# Mean FCP : 0.6862
# ------------
# -94

# %% [markdown]
# best RMSE is obtained for a learning rate of 0.001 with regularization 0.1 and number of factors = 80
