# %%
import pandas as pd
import pickle
import random
from surprise import prediction_algorithms as pa
from surprise import Dataset, Reader, GridSearch, accuracy, dump
from surprise import evaluate, print_perf
from sklearn.model_selection import train_test_split
import time

# %%
data = pd.read_csv('./ml-100k/data.csv')
df = pd.DataFrame(data)
df.drop('timestamp', axis=1, inplace=True)
reader = Reader(rating_scale=(1, 5))
dataset = Dataset.load_from_df(df[['userId', 'movieId', 'rating']], reader)
raw_ratings = dataset.raw_ratings
random.shuffle(raw_ratings)
threshold = int(.8 * len(raw_ratings))
A_raw_ratings = raw_ratings[:threshold]
B_raw_ratings = raw_ratings[threshold:]
dataset.raw_ratings = A_raw_ratings
dataset.split(n_folds=5)

# %%
res_tune = {}
latent_factors = [5,10,15,20,25,30]
regularizations = [0.5,0.2,0.1,0.05,0.02,0.01,0.005]
for regularization in regularizations:
    print "regularization : ", regularization
    start_time = int(time.time())
    param_grid = {'n_factors': latent_factors, 'n_epochs': [100], 'reg_pu': [regularization], 'reg_qi': [regularization]}
    grid_search = GridSearch(pa.matrix_factorization.NMF, param_grid=param_grid, measures=['MAE', 'RMSE', 'FCP'])
    grid_search.evaluate(dataset)
    end_time = int(time.time())
    res_tune[regularization] = grid_search.cv_results
    print (start_time-end_time)/len(latent_factors)
pickle.dump(res_tune, open("nmf_result1","wb"))
# Out:
# regularization :  0.5
# [{'n_factors': 5, 'reg_qi': 0.5, 'reg_pu': 0.5, 'n_epochs': 100}, {'n_factors': 10, 'reg_qi': 0.5, 'reg_pu': 0.5, 'n_epochs': 100}, {'n_factors': 15, 'reg_qi': 0.5, 'reg_pu': 0.5, 'n_epochs': 100}, {'n_factors': 20, 'reg_qi': 0.5, 'reg_pu': 0.5, 'n_epochs': 100}, {'n_factors': 25, 'reg_qi': 0.5, 'reg_pu': 0.5, 'n_epochs': 100}, {'n_factors': 30, 'reg_qi': 0.5, 'reg_pu': 0.5, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 6
# params:  {'n_factors': 5, 'reg_qi': 0.5, 'reg_pu': 0.5, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8866
# Mean RMSE: 1.0731
# Mean FCP : 0.6880
# ------------
# ------------
# Parameters combination 2 of 6
# params:  {'n_factors': 10, 'reg_qi': 0.5, 'reg_pu': 0.5, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8866
# Mean RMSE: 1.0731
# Mean FCP : 0.6880
# ------------
# ------------
# Parameters combination 3 of 6
# params:  {'n_factors': 15, 'reg_qi': 0.5, 'reg_pu': 0.5, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8866
# Mean RMSE: 1.0731
# Mean FCP : 0.6880
# ------------
# ------------
# Parameters combination 4 of 6
# params:  {'n_factors': 20, 'reg_qi': 0.5, 'reg_pu': 0.5, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8866
# Mean RMSE: 1.0731
# Mean FCP : 0.6880
# ------------
# ------------
# Parameters combination 5 of 6
# params:  {'n_factors': 25, 'reg_qi': 0.5, 'reg_pu': 0.5, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8866
# Mean RMSE: 1.0731
# Mean FCP : 0.6880
# ------------
# ------------
# Parameters combination 6 of 6
# params:  {'n_factors': 30, 'reg_qi': 0.5, 'reg_pu': 0.5, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8866
# Mean RMSE: 1.0731
# Mean FCP : 0.6880
# ------------
# -34
# regularization :  0.2
# [{'n_factors': 5, 'reg_qi': 0.2, 'reg_pu': 0.2, 'n_epochs': 100}, {'n_factors': 10, 'reg_qi': 0.2, 'reg_pu': 0.2, 'n_epochs': 100}, {'n_factors': 15, 'reg_qi': 0.2, 'reg_pu': 0.2, 'n_epochs': 100}, {'n_factors': 20, 'reg_qi': 0.2, 'reg_pu': 0.2, 'n_epochs': 100}, {'n_factors': 25, 'reg_qi': 0.2, 'reg_pu': 0.2, 'n_epochs': 100}, {'n_factors': 30, 'reg_qi': 0.2, 'reg_pu': 0.2, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 6
# params:  {'n_factors': 5, 'reg_qi': 0.2, 'reg_pu': 0.2, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7699
# Mean RMSE: 0.9589
# Mean FCP : 0.6987
# ------------
# ------------
# Parameters combination 2 of 6
# params:  {'n_factors': 10, 'reg_qi': 0.2, 'reg_pu': 0.2, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7684
# Mean RMSE: 0.9570
# Mean FCP : 0.7022
# ------------
# ------------
# Parameters combination 3 of 6
# params:  {'n_factors': 15, 'reg_qi': 0.2, 'reg_pu': 0.2, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7677
# Mean RMSE: 0.9558
# Mean FCP : 0.7014
# ------------
# ------------
# Parameters combination 4 of 6
# params:  {'n_factors': 20, 'reg_qi': 0.2, 'reg_pu': 0.2, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7678
# Mean RMSE: 0.9559
# Mean FCP : 0.7024
# ------------
# ------------
# Parameters combination 5 of 6
# params:  {'n_factors': 25, 'reg_qi': 0.2, 'reg_pu': 0.2, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7677
# Mean RMSE: 0.9556
# Mean FCP : 0.7031
# ------------
# ------------
# Parameters combination 6 of 6
# params:  {'n_factors': 30, 'reg_qi': 0.2, 'reg_pu': 0.2, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7669
# Mean RMSE: 0.9545
# Mean FCP : 0.7036
# ------------
# -33
# regularization :  0.1
# [{'n_factors': 5, 'reg_qi': 0.1, 'reg_pu': 0.1, 'n_epochs': 100}, {'n_factors': 10, 'reg_qi': 0.1, 'reg_pu': 0.1, 'n_epochs': 100}, {'n_factors': 15, 'reg_qi': 0.1, 'reg_pu': 0.1, 'n_epochs': 100}, {'n_factors': 20, 'reg_qi': 0.1, 'reg_pu': 0.1, 'n_epochs': 100}, {'n_factors': 25, 'reg_qi': 0.1, 'reg_pu': 0.1, 'n_epochs': 100}, {'n_factors': 30, 'reg_qi': 0.1, 'reg_pu': 0.1, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 6
# params:  {'n_factors': 5, 'reg_qi': 0.1, 'reg_pu': 0.1, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7573
# Mean RMSE: 0.9558
# Mean FCP : 0.6954
# ------------
# ------------
# Parameters combination 2 of 6
# params:  {'n_factors': 10, 'reg_qi': 0.1, 'reg_pu': 0.1, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7514
# Mean RMSE: 0.9498
# Mean FCP : 0.6970
# ------------
# ------------
# Parameters combination 3 of 6
# params:  {'n_factors': 15, 'reg_qi': 0.1, 'reg_pu': 0.1, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7532
# Mean RMSE: 0.9505
# Mean FCP : 0.7000
# ------------
# ------------
# Parameters combination 4 of 6
# params:  {'n_factors': 20, 'reg_qi': 0.1, 'reg_pu': 0.1, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7510
# Mean RMSE: 0.9474
# Mean FCP : 0.7003
# ------------
# ------------
# Parameters combination 5 of 6
# params:  {'n_factors': 25, 'reg_qi': 0.1, 'reg_pu': 0.1, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7512
# Mean RMSE: 0.9472
# Mean FCP : 0.7010
# ------------
# ------------
# Parameters combination 6 of 6
# params:  {'n_factors': 30, 'reg_qi': 0.1, 'reg_pu': 0.1, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7486
# Mean RMSE: 0.9435
# Mean FCP : 0.7031
# ------------
# -32
# regularization :  0.05
# [{'n_factors': 5, 'reg_qi': 0.05, 'reg_pu': 0.05, 'n_epochs': 100}, {'n_factors': 10, 'reg_qi': 0.05, 'reg_pu': 0.05, 'n_epochs': 100}, {'n_factors': 15, 'reg_qi': 0.05, 'reg_pu': 0.05, 'n_epochs': 100}, {'n_factors': 20, 'reg_qi': 0.05, 'reg_pu': 0.05, 'n_epochs': 100}, {'n_factors': 25, 'reg_qi': 0.05, 'reg_pu': 0.05, 'n_epochs': 100}, {'n_factors': 30, 'reg_qi': 0.05, 'reg_pu': 0.05, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 6
# params:  {'n_factors': 5, 'reg_qi': 0.05, 'reg_pu': 0.05, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7812
# Mean RMSE: 0.9838
# Mean FCP : 0.6842
# ------------
# ------------
# Parameters combination 2 of 6
# params:  {'n_factors': 10, 'reg_qi': 0.05, 'reg_pu': 0.05, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7724
# Mean RMSE: 0.9836
# Mean FCP : 0.6848
# ------------
# ------------
# Parameters combination 3 of 6
# params:  {'n_factors': 15, 'reg_qi': 0.05, 'reg_pu': 0.05, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7714
# Mean RMSE: 0.9850
# Mean FCP : 0.6821
# ------------
# ------------
# Parameters combination 4 of 6
# params:  {'n_factors': 20, 'reg_qi': 0.05, 'reg_pu': 0.05, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7671
# Mean RMSE: 0.9816
# Mean FCP : 0.6811
# ------------
# ------------
# Parameters combination 5 of 6
# params:  {'n_factors': 25, 'reg_qi': 0.05, 'reg_pu': 0.05, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7656
# Mean RMSE: 0.9790
# Mean FCP : 0.6839
# ------------
# ------------
# Parameters combination 6 of 6
# params:  {'n_factors': 30, 'reg_qi': 0.05, 'reg_pu': 0.05, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7638
# Mean RMSE: 0.9766
# Mean FCP : 0.6844
# ------------
# -31
# regularization :  0.02
# [{'n_factors': 5, 'reg_qi': 0.02, 'reg_pu': 0.02, 'n_epochs': 100}, {'n_factors': 10, 'reg_qi': 0.02, 'reg_pu': 0.02, 'n_epochs': 100}, {'n_factors': 15, 'reg_qi': 0.02, 'reg_pu': 0.02, 'n_epochs': 100}, {'n_factors': 20, 'reg_qi': 0.02, 'reg_pu': 0.02, 'n_epochs': 100}, {'n_factors': 25, 'reg_qi': 0.02, 'reg_pu': 0.02, 'n_epochs': 100}, {'n_factors': 30, 'reg_qi': 0.02, 'reg_pu': 0.02, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 6
# params:  {'n_factors': 5, 'reg_qi': 0.02, 'reg_pu': 0.02, 'n_epochs': 100}
# ------------
# Mean MAE : 1.0202
# Mean RMSE: 1.2206
# Mean FCP : 0.6799
# ------------
# ------------
# Parameters combination 2 of 6
# params:  {'n_factors': 10, 'reg_qi': 0.02, 'reg_pu': 0.02, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8247
# Mean RMSE: 1.0378
# Mean FCP : 0.6669
# ------------
# ------------
# Parameters combination 3 of 6
# params:  {'n_factors': 15, 'reg_qi': 0.02, 'reg_pu': 0.02, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8005
# Mean RMSE: 1.0371
# Mean FCP : 0.6622
# ------------
# ------------
# Parameters combination 4 of 6
# params:  {'n_factors': 20, 'reg_qi': 0.02, 'reg_pu': 0.02, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8145
# Mean RMSE: 1.0648
# Mean FCP : 0.6633
# ------------
# ------------
# Parameters combination 5 of 6
# params:  {'n_factors': 25, 'reg_qi': 0.02, 'reg_pu': 0.02, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8395
# Mean RMSE: 1.1014
# Mean FCP : 0.6577
# ------------
# ------------
# Parameters combination 6 of 6
# params:  {'n_factors': 30, 'reg_qi': 0.02, 'reg_pu': 0.02, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8592
# Mean RMSE: 1.1317
# Mean FCP : 0.6527
# ------------
# -31
# regularization :  0.01
# [{'n_factors': 5, 'reg_qi': 0.01, 'reg_pu': 0.01, 'n_epochs': 100}, {'n_factors': 10, 'reg_qi': 0.01, 'reg_pu': 0.01, 'n_epochs': 100}, {'n_factors': 15, 'reg_qi': 0.01, 'reg_pu': 0.01, 'n_epochs': 100}, {'n_factors': 20, 'reg_qi': 0.01, 'reg_pu': 0.01, 'n_epochs': 100}, {'n_factors': 25, 'reg_qi': 0.01, 'reg_pu': 0.01, 'n_epochs': 100}, {'n_factors': 30, 'reg_qi': 0.01, 'reg_pu': 0.01, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 6
# params:  {'n_factors': 5, 'reg_qi': 0.01, 'reg_pu': 0.01, 'n_epochs': 100}
# ------------
# Mean MAE : 1.3887
# Mean RMSE: 1.5966
# Mean FCP : 0.6716
# ------------
# ------------
# Parameters combination 2 of 6
# params:  {'n_factors': 10, 'reg_qi': 0.01, 'reg_pu': 0.01, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8910
# Mean RMSE: 1.1029
# Mean FCP : 0.6653
# ------------
# ------------
# Parameters combination 3 of 6
# params:  {'n_factors': 15, 'reg_qi': 0.01, 'reg_pu': 0.01, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8170
# Mean RMSE: 1.0673
# Mean FCP : 0.6554
# ------------
# ------------
# Parameters combination 4 of 6
# params:  {'n_factors': 20, 'reg_qi': 0.01, 'reg_pu': 0.01, 'n_epochs': 100}
# ------------
# Mean MAE : 0.9024
# Mean RMSE: 1.1897
# Mean FCP : 0.6379
# ------------
# ------------
# Parameters combination 5 of 6
# params:  {'n_factors': 25, 'reg_qi': 0.01, 'reg_pu': 0.01, 'n_epochs': 100}
# ------------
# Mean MAE : 1.0028
# Mean RMSE: 1.3121
# Mean FCP : 0.5989
# ------------
# ------------
# Parameters combination 6 of 6
# params:  {'n_factors': 30, 'reg_qi': 0.01, 'reg_pu': 0.01, 'n_epochs': 100}
# ------------
# Mean MAE : 1.0780
# Mean RMSE: 1.3985
# Mean FCP : 0.5541
# ------------
# -33
# regularization :  0.005
# [{'n_factors': 5, 'reg_qi': 0.005, 'reg_pu': 0.005, 'n_epochs': 100}, {'n_factors': 10, 'reg_qi': 0.005, 'reg_pu': 0.005, 'n_epochs': 100}, {'n_factors': 15, 'reg_qi': 0.005, 'reg_pu': 0.005, 'n_epochs': 100}, {'n_factors': 20, 'reg_qi': 0.005, 'reg_pu': 0.005, 'n_epochs': 100}, {'n_factors': 25, 'reg_qi': 0.005, 'reg_pu': 0.005, 'n_epochs': 100}, {'n_factors': 30, 'reg_qi': 0.005, 'reg_pu': 0.005, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 6
# params:  {'n_factors': 5, 'reg_qi': 0.005, 'reg_pu': 0.005, 'n_epochs': 100}
# ------------
# Mean MAE : 1.7015
# Mean RMSE: 1.9125
# Mean FCP : 0.6690
# ------------
# ------------
# Parameters combination 2 of 6
# params:  {'n_factors': 10, 'reg_qi': 0.005, 'reg_pu': 0.005, 'n_epochs': 100}
# ------------
# Mean MAE : 0.9771
# Mean RMSE: 1.1893
# Mean FCP : 0.6621
# ------------
# ------------
# Parameters combination 3 of 6
# params:  {'n_factors': 15, 'reg_qi': 0.005, 'reg_pu': 0.005, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8364
# Mean RMSE: 1.0971
# Mean FCP : 0.6507
# ------------
# ------------
# Parameters combination 4 of 6
# params:  {'n_factors': 20, 'reg_qi': 0.005, 'reg_pu': 0.005, 'n_epochs': 100}
# ------------
# Mean MAE : 1.0114
# Mean RMSE: 1.3252
# Mean FCP : 0.5906
# ------------
# ------------
# Parameters combination 5 of 6
# params:  {'n_factors': 25, 'reg_qi': 0.005, 'reg_pu': 0.005, 'n_epochs': 100}
# ------------
# Mean MAE : 1.1632
# Mean RMSE: 1.4957
# Mean FCP : 0.4988
# ------------
# ------------
# Parameters combination 6 of 6
# params:  {'n_factors': 30, 'reg_qi': 0.005, 'reg_pu': 0.005, 'n_epochs': 100}
# ------------
# Mean MAE : 1.2544
# Mean RMSE: 1.5962
# Mean FCP : 0.4183
# ------------
# -39

# %% [markdown]
# vary the number of factors and regularization for the user and item vectors
# the best solutions are obtained for number of factors close to 20 and with regularization of 0.1
# we choose number of factors as 20, to not overfit the model

# %%
for reg in res_tune:
    c = 0
    print "regularization : ", reg 
    s = ""
    for i in res_tune[reg]['RMSE']:
        s+=str(latent_factors[c])+"||"+str(i)+"   "
        c+=1
    print s
# Out:
# regularization :  0.5
# 5||1.07308604174   10||1.07309135058   15||1.07309299279   20||1.07309222039   25||1.07309052124   30||1.07309095147
# regularization :  0.005
# 5||1.91250738147   10||1.18932411735   15||1.09713356077   20||1.32522968925   25||1.49567172442   30||1.59619051221
# regularization :  0.1
# 5||0.955835794036   10||0.949769414646   15||0.950549178723   20||0.947425118203   25||0.947188897764   30||0.943521413139
# regularization :  0.05
# 5||0.983817796788   10||0.98361691683   15||0.985018167585   20||0.981587486482   25||0.97904367206   30||0.976582431465
# regularization :  0.2
# 5||0.958866705685   10||0.957038052954   15||0.955767971055   20||0.955937563144   25||0.955648293572   30||0.954529576677
# regularization :  0.01
# 5||1.59664307885   10||1.10287826086   15||1.06731450563   20||1.18968878497   25||1.31206178628   30||1.39850305788
# regularization :  0.02
# 5||1.22060010699   10||1.03780494421   15||1.03710508609   20||1.06478667118   25||1.10142893328   30||1.13167028519

# %%
res_tune = {}
latent_factors = [15,20,25]
regularizations = [0.2,0.1,0.05,0.02]
learn_bias = [0.02,0.01,0.005,0.002,0.001]
for regularization in regularizations:
    res_tune[regularization] = {}
    for lb in learn_bias:
        print "regularization : ", regularization, " bias : ", lb
        start_time = int(time.time())
        param_grid = {'n_factors': latent_factors, 'n_epochs': [100], 'reg_pu': [regularization], 'reg_qi': [regularization], 
                      'biased': [True], 'lr_bu': [lb], 'lr_bi': [lb], 'reg_bu': [regularization], 'reg_bi': [regularization]}
        grid_search = GridSearch(pa.matrix_factorization.NMF, param_grid=param_grid, measures=['MAE', 'RMSE', 'FCP'])
        grid_search.evaluate(dataset)
        end_time = int(time.time())
        print (start_time-end_time)
        res_tune[regularization][lb] = grid_search.cv_results
pickle.dump(res_tune, open("nmf_result2","wb"))
# Out:
# regularization :  0.2  bias :  0.02
# [{'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7939
# Mean RMSE: 1.0004
# Mean FCP : 0.6808
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7916
# Mean RMSE: 1.0049
# Mean FCP : 0.6746
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7929
# Mean RMSE: 1.0106
# Mean FCP : 0.6781
# ------------
# -36
# regularization :  0.2  bias :  0.01
# [{'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7548
# Mean RMSE: 0.9493
# Mean FCP : 0.6902
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7556
# Mean RMSE: 0.9507
# Mean FCP : 0.6900
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7604
# Mean RMSE: 0.9594
# Mean FCP : 0.6880
# ------------
# -39
# regularization :  0.2  bias :  0.005
# [{'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7608
# Mean RMSE: 0.9615
# Mean FCP : 0.6877
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7606
# Mean RMSE: 0.9604
# Mean FCP : 0.6888
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7754
# Mean RMSE: 0.9861
# Mean FCP : 0.6802
# ------------
# -36
# regularization :  0.2  bias :  0.002
# [{'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7535
# Mean RMSE: 0.9475
# Mean FCP : 0.6905
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7535
# Mean RMSE: 0.9475
# Mean FCP : 0.6906
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7854
# Mean RMSE: 0.9953
# Mean FCP : 0.6774
# ------------
# -36
# regularization :  0.2  bias :  0.001
# [{'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7556
# Mean RMSE: 0.9492
# Mean FCP : 0.6895
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7557
# Mean RMSE: 0.9492
# Mean FCP : 0.6895
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.2, 'reg_pu': 0.2, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.2, 'reg_qi': 0.2, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7557
# Mean RMSE: 0.9492
# Mean FCP : 0.6895
# ------------
# -38
# regularization :  0.1  bias :  0.02
# [{'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7461
# Mean RMSE: 0.9431
# Mean FCP : 0.6941
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7921
# Mean RMSE: 1.0128
# Mean FCP : 0.6737
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 0.9108
# Mean RMSE: 1.1713
# Mean FCP : 0.6285
# ------------
# -36
# regularization :  0.1  bias :  0.01
# [{'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7435
# Mean RMSE: 0.9399
# Mean FCP : 0.6946
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7706
# Mean RMSE: 0.9829
# Mean FCP : 0.6788
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8020
# Mean RMSE: 1.0285
# Mean FCP : 0.6758
# ------------
# -36
# regularization :  0.1  bias :  0.005
# [{'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7535
# Mean RMSE: 0.9569
# Mean FCP : 0.6921
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.9258
# Mean RMSE: 1.1982
# Mean FCP : 0.6356
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8302
# Mean RMSE: 1.0769
# Mean FCP : 0.6620
# ------------
# -40
# regularization :  0.1  bias :  0.002
# [{'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7407
# Mean RMSE: 0.9360
# Mean FCP : 0.6956
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.9254
# Mean RMSE: 1.1639
# Mean FCP : 0.6428
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 1.0060
# Mean RMSE: 1.2716
# Mean FCP : 0.6129
# ------------
# -35
# regularization :  0.1  bias :  0.001
# [{'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7426
# Mean RMSE: 0.9375
# Mean FCP : 0.6945
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7415
# Mean RMSE: 0.9364
# Mean FCP : 0.6951
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.1, 'reg_pu': 0.1, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.1, 'reg_qi': 0.1, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7408
# Mean RMSE: 0.9351
# Mean FCP : 0.6956
# ------------
# -34
# regularization :  0.05  bias :  0.02
# [{'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7484
# Mean RMSE: 0.9535
# Mean FCP : 0.6901
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8124
# Mean RMSE: 1.0481
# Mean FCP : 0.6709
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 0.9497
# Mean RMSE: 1.2398
# Mean FCP : 0.6376
# ------------
# -36
# regularization :  0.05  bias :  0.01
# [{'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7757
# Mean RMSE: 0.9959
# Mean FCP : 0.6843
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.9035
# Mean RMSE: 1.1768
# Mean FCP : 0.6183
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 0.9935
# Mean RMSE: 1.2828
# Mean FCP : 0.6103
# ------------
# -33
# regularization :  0.05  bias :  0.005
# [{'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8551
# Mean RMSE: 1.1045
# Mean FCP : 0.6584
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8847
# Mean RMSE: 1.1549
# Mean FCP : 0.6454
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 1.2173
# Mean RMSE: 1.5279
# Mean FCP : 0.5556
# ------------
# -35
# regularization :  0.05  bias :  0.002
# [{'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7397
# Mean RMSE: 0.9413
# Mean FCP : 0.6938
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.8022
# Mean RMSE: 1.0358
# Mean FCP : 0.6735
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 1.1235
# Mean RMSE: 1.4531
# Mean FCP : 0.6002
# ------------
# -35
# regularization :  0.05  bias :  0.001
# [{'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7398
# Mean RMSE: 0.9409
# Mean FCP : 0.6931
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7397
# Mean RMSE: 0.9417
# Mean FCP : 0.6901
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.05, 'reg_pu': 0.05, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.05, 'reg_qi': 0.05, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7373
# Mean RMSE: 0.9391
# Mean FCP : 0.6958
# ------------
# -43
# regularization :  0.02  bias :  0.02
# [{'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7768
# Mean RMSE: 1.0007
# Mean FCP : 0.6750
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.9229
# Mean RMSE: 1.2086
# Mean FCP : 0.6476
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 1.1949
# Mean RMSE: 1.5007
# Mean FCP : 0.5308
# ------------
# -39
# regularization :  0.02  bias :  0.01
# [{'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.9288
# Mean RMSE: 1.2077
# Mean FCP : 0.6319
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 1.1659
# Mean RMSE: 1.5012
# Mean FCP : 0.5242
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 1.0368
# Mean RMSE: 1.3403
# Mean FCP : 0.6046
# ------------
# -34
# regularization :  0.02  bias :  0.005
# [{'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.9231
# Mean RMSE: 1.1929
# Mean FCP : 0.6385
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 1.1083
# Mean RMSE: 1.4093
# Mean FCP : 0.5372
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 1.0334
# Mean RMSE: 1.3492
# Mean FCP : 0.6028
# ------------
# -38
# regularization :  0.02  bias :  0.002
# [{'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7650
# Mean RMSE: 0.9819
# Mean FCP : 0.6787
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 1.0215
# Mean RMSE: 1.2850
# Mean FCP : 0.6041
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 1.3139
# Mean RMSE: 1.6774
# Mean FCP : 0.4828
# ------------
# -39
# regularization :  0.02  bias :  0.001
# [{'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 15, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 20, 'n_epochs': 100}, {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 25, 'n_epochs': 100}]
# ------------
# Parameters combination 1 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 15, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7632
# Mean RMSE: 0.9794
# Mean FCP : 0.6736
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 20, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7666
# Mean RMSE: 0.9835
# Mean FCP : 0.6739
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'biased': True, 'reg_bi': 0.02, 'reg_pu': 0.02, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.02, 'reg_qi': 0.02, 'n_factors': 25, 'n_epochs': 100}
# ------------
# Mean MAE : 0.7696
# Mean RMSE: 0.9886
# Mean FCP : 0.6719
# ------------
# -36

# %% [markdown]
# for a biased version vary the number of factors and regularization close in a range close to optimal solution and vary the learning rate for the bias

# %%
for reg in res_tune:
    for bias in res_tune[reg]:
        c = 0
        print "regularization : ", reg, " bias : ", bias 
        s = ""
        for i in res_tune[reg][bias]['RMSE']:
            s+=str(latent_factors[c])+"||"+str(i)+"   "
            c+=1
        print s
# Out:
# regularization :  0.05  bias :  0.001
# 15||0.940895079056   20||0.941689980199   25||0.939116823657
# regularization :  0.05  bias :  0.005
# 15||1.10447613708   20||1.15486679336   25||1.52789906192
# regularization :  0.05  bias :  0.002
# 15||0.941254990968   20||1.0358177903   25||1.45308509002
# regularization :  0.05  bias :  0.01
# 15||0.9958792156   20||1.17675987434   25||1.28278623299
# regularization :  0.05  bias :  0.02
# 15||0.953456768683   20||1.04811593873   25||1.23977754099
# regularization :  0.02  bias :  0.001
# 15||0.979408311318   20||0.983514337539   25||0.988571619378
# regularization :  0.02  bias :  0.005
# 15||1.19294864039   20||1.40925861834   25||1.34915227895
# regularization :  0.02  bias :  0.002
# 15||0.981908301468   20||1.28495264158   25||1.67735246476
# regularization :  0.02  bias :  0.01
# 15||1.20768878809   20||1.50119088556   25||1.34032098212
# regularization :  0.02  bias :  0.02
# 15||1.00069139131   20||1.20860409605   25||1.50071317101
# regularization :  0.1  bias :  0.001
# 15||0.937504212679   20||0.936371724466   25||0.935109681181
# regularization :  0.1  bias :  0.005
# 15||0.95689631054   20||1.19816705646   25||1.07694273571
# regularization :  0.1  bias :  0.002
# 15||0.936013794101   20||1.16391477476   25||1.27159365334
# regularization :  0.1  bias :  0.01
# 15||0.939915191638   20||0.982908629577   25||1.02854337616
# regularization :  0.1  bias :  0.02
# 15||0.943119869515   20||1.01275673033   25||1.17128869102
# regularization :  0.2  bias :  0.001
# 15||0.949212933993   20||0.949175735165   25||0.949156823581
# regularization :  0.2  bias :  0.005
# 15||0.961452400127   20||0.960389331981   25||0.986148304443
# regularization :  0.2  bias :  0.002
# 15||0.947544861228   20||0.947490104749   25||0.99526475504
# regularization :  0.2  bias :  0.01
# 15||0.949310808303   20||0.950713803832   25||0.959368395614
# regularization :  0.2  bias :  0.02
# 15||1.00044366762   20||1.00491366754   25||1.01056175043

# %% [markdown]
# the best solution is obtained for the model with the parameters
# number of factors = 20
# regularization = 0.1
# and learning rate for bias = 0.001
# not to learn the model with these parameters

# %%
start_time = int(time.time())
trainset = dataset.build_full_trainset()
algo = pa.matrix_factorization.NMF(n_factors=20, n_epochs=100, biased=True, reg_pu=0.1, reg_qi=0.1, reg_bu=0.1, reg_bi=0.1, lr_bu=0.001, lr_bi=0.001)
algo.train(trainset)
end_time = int(time.time())
print (start_time-end_time)
testset = dataset.construct_testset(B_raw_ratings)
predictions = algo.test(testset)
print 'Unbiased accuracy on B,', accuracy.rmse(predictions)
accuracy.rmse(predictions)
accuracy.mae(predictions)
accuracy.fcp(predictions)
dump.dump('./nmf_algo',predictions,algo)
# Out:
# -3
# Unbiased accuracy on B,RMSE: 0.9292
#  0.929151467398
# RMSE: 0.9292
# MAE:  0.7383
# FCP:  0.7112
