# %%
import pandas as pd
import pickle
import random
from surprise import prediction_algorithms as pa
from surprise import Dataset, Reader, GridSearch, accuracy, dump
from surprise import evaluate, print_perf
from sklearn.model_selection import train_test_split
import time

# %%
data = pd.read_csv('./ml-100k/data.csv')
df = pd.DataFrame(data)
df.drop('timestamp', axis=1, inplace=True)
reader = Reader(rating_scale=(1, 5))
dataset = Dataset.load_from_df(df[['userId', 'movieId', 'rating']], reader)
raw_ratings = dataset.raw_ratings
random.shuffle(raw_ratings)
threshold = int(.8 * len(raw_ratings))
A_raw_ratings = raw_ratings[:threshold]
B_raw_ratings = raw_ratings[threshold:]
dataset.raw_ratings = A_raw_ratings
dataset.split(n_folds=5)

# %%
res_tune = {}
latent_factors = [5,10,15,20,25,30]
regularizations = [0.5,0.2,0.1,0.05,0.02,0.01,0.005]
for regularization in regularizations:
    print("regularization : ", regularization)
    print("start time : ", int(time.time()))
    param_grid = {'n_factors': latent_factors, 'n_epochs': [100], 'reg_pu': [regularization], 'reg_qi': [regularization]}
    grid_search = GridSearch(pa.matrix_factorization.NMF, param_grid=param_grid, measures=['MAE', 'RMSE', 'FCP'])
    grid_search.evaluate(dataset)
    print("end time : ", int(time.time()))
    res_tune[regularization] = grid_search.cv_results
pickle.dump(res_tune, open("nmf_result1","wb"))
# Out:
# regularization :  0.5
# start time :  1509637446
# [{'n_factors': 5, 'n_epochs': 100, 'reg_pu': 0.5, 'reg_qi': 0.5}, {'n_factors': 10, 'n_epochs': 100, 'reg_pu': 0.5, 'reg_qi': 0.5}, {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.5, 'reg_qi': 0.5}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.5, 'reg_qi': 0.5}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.5, 'reg_qi': 0.5}, {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0.5, 'reg_qi': 0.5}]
# ------------
# Parameters combination 1 of 6
# params:  {'n_factors': 5, 'n_epochs': 100, 'reg_pu': 0.5, 'reg_qi': 0.5}
# ------------
# Mean MAE : 0.8860
# Mean RMSE: 1.0727
# Mean FCP : 0.6889
# ------------
# ------------
# Parameters combination 2 of 6
# params:  {'n_factors': 10, 'n_epochs': 100, 'reg_pu': 0.5, 'reg_qi': 0.5}
# ------------
# Mean MAE : 0.8860
# Mean RMSE: 1.0727
# Mean FCP : 0.6889
# ------------
# ------------
# Parameters combination 3 of 6
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.5, 'reg_qi': 0.5}
# ------------
# Mean MAE : 0.8860
# Mean RMSE: 1.0727
# Mean FCP : 0.6889
# ------------
# ------------
# Parameters combination 4 of 6
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.5, 'reg_qi': 0.5}
# ------------
# Mean MAE : 0.8860
# Mean RMSE: 1.0727
# Mean FCP : 0.6889
# ------------
# ------------
# Parameters combination 5 of 6
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.5, 'reg_qi': 0.5}
# ------------
# Mean MAE : 0.8860
# Mean RMSE: 1.0727
# Mean FCP : 0.6889
# ------------
# ------------
# Parameters combination 6 of 6
# params:  {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0.5, 'reg_qi': 0.5}
# ------------
# Mean MAE : 0.8860
# Mean RMSE: 1.0727
# Mean FCP : 0.6889
# ------------
# end time :  1509637673
# regularization :  0.2
# start time :  1509637673
# [{'n_factors': 5, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2}, {'n_factors': 10, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2}, {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2}, {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2}]
# ------------
# Parameters combination 1 of 6
# params:  {'n_factors': 5, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2}
# ------------
# Mean MAE : 0.7750
# Mean RMSE: 0.9645
# Mean FCP : 0.6971
# ------------
# ------------
# Parameters combination 2 of 6
# params:  {'n_factors': 10, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2}
# ------------
# Mean MAE : 0.7716
# Mean RMSE: 0.9600
# Mean FCP : 0.7011
# ------------
# ------------
# Parameters combination 3 of 6
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2}
# ------------
# Mean MAE : 0.7690
# Mean RMSE: 0.9568
# Mean FCP : 0.7029
# ------------
# ------------
# Parameters combination 4 of 6
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2}
# ------------
# Mean MAE : 0.7690
# Mean RMSE: 0.9565
# Mean FCP : 0.7028
# ------------
# ------------
# Parameters combination 5 of 6
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2}
# ------------
# Mean MAE : 0.7691
# Mean RMSE: 0.9569
# Mean FCP : 0.7034
# ------------
# ------------
# Parameters combination 6 of 6
# params:  {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2}
# ------------
# Mean MAE : 0.7687
# Mean RMSE: 0.9563
# Mean FCP : 0.7034
# ------------
# end time :  1509637905
# regularization :  0.1
# start time :  1509637905
# [{'n_factors': 5, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1}, {'n_factors': 10, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1}, {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1}, {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1}]
# ------------
# Parameters combination 1 of 6
# params:  {'n_factors': 5, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1}
# ------------
# Mean MAE : 0.7575
# Mean RMSE: 0.9558
# Mean FCP : 0.6961
# ------------
# ------------
# Parameters combination 2 of 6
# params:  {'n_factors': 10, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1}
# ------------
# Mean MAE : 0.7545
# Mean RMSE: 0.9526
# Mean FCP : 0.7011
# ------------
# ------------
# Parameters combination 3 of 6
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1}
# ------------
# Mean MAE : 0.7537
# Mean RMSE: 0.9513
# Mean FCP : 0.7022
# ------------
# ------------
# Parameters combination 4 of 6
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1}
# ------------
# Mean MAE : 0.7529
# Mean RMSE: 0.9500
# Mean FCP : 0.7011
# ------------
# ------------
# Parameters combination 5 of 6
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1}
# ------------
# Mean MAE : 0.7506
# Mean RMSE: 0.9458
# Mean FCP : 0.7026
# ------------
# ------------
# Parameters combination 6 of 6
# params:  {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1}
# ------------
# Mean MAE : 0.7505
# Mean RMSE: 0.9455
# Mean FCP : 0.7038
# ------------
# end time :  1509638133
# regularization :  0.05
# start time :  1509638133
# [{'n_factors': 5, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05}, {'n_factors': 10, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05}, {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05}, {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05}]
# ------------
# Parameters combination 1 of 6
# params:  {'n_factors': 5, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05}
# ------------
# Mean MAE : 0.7824
# Mean RMSE: 0.9859
# Mean FCP : 0.6860
# ------------
# ------------
# Parameters combination 2 of 6
# params:  {'n_factors': 10, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05}
# ------------
# Mean MAE : 0.7755
# Mean RMSE: 0.9854
# Mean FCP : 0.6828
# ------------
# ------------
# Parameters combination 3 of 6
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05}
# ------------
# Mean MAE : 0.7723
# Mean RMSE: 0.9855
# Mean FCP : 0.6821
# ------------
# ------------
# Parameters combination 4 of 6
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05}
# ------------
# Mean MAE : 0.7714
# Mean RMSE: 0.9849
# Mean FCP : 0.6809
# ------------
# ------------
# Parameters combination 5 of 6
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05}
# ------------
# Mean MAE : 0.7682
# Mean RMSE: 0.9815
# Mean FCP : 0.6806
# ------------
# ------------
# Parameters combination 6 of 6
# params:  {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05}
# ------------
# Mean MAE : 0.7658
# Mean RMSE: 0.9789
# Mean FCP : 0.6828
# ------------
# end time :  1509638362
# regularization :  0.02
# start time :  1509638362
# [{'n_factors': 5, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02}, {'n_factors': 10, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02}, {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02}, {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02}]
# ------------
# Parameters combination 1 of 6
# params:  {'n_factors': 5, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02}
# ------------
# Mean MAE : 1.0196
# Mean RMSE: 1.2208
# Mean FCP : 0.6791
# ------------
# ------------
# Parameters combination 2 of 6
# params:  {'n_factors': 10, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02}
# ------------
# Mean MAE : 0.8284
# Mean RMSE: 1.0437
# Mean FCP : 0.6665
# ------------
# ------------
# Parameters combination 3 of 6
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02}
# ------------
# Mean MAE : 0.8010
# Mean RMSE: 1.0358
# Mean FCP : 0.6616
# ------------
# ------------
# Parameters combination 4 of 6
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02}
# ------------
# Mean MAE : 0.8202
# Mean RMSE: 1.0729
# Mean FCP : 0.6569
# ------------
# ------------
# Parameters combination 5 of 6
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02}
# ------------
# Mean MAE : 0.8411
# Mean RMSE: 1.1026
# Mean FCP : 0.6555
# ------------
# ------------
# Parameters combination 6 of 6
# params:  {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02}
# ------------
# Mean MAE : 0.8615
# Mean RMSE: 1.1325
# Mean FCP : 0.6517
# ------------
# end time :  1509638597
# regularization :  0.01
# start time :  1509638597
# [{'n_factors': 5, 'n_epochs': 100, 'reg_pu': 0.01, 'reg_qi': 0.01}, {'n_factors': 10, 'n_epochs': 100, 'reg_pu': 0.01, 'reg_qi': 0.01}, {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.01, 'reg_qi': 0.01}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.01, 'reg_qi': 0.01}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.01, 'reg_qi': 0.01}, {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0.01, 'reg_qi': 0.01}]
# ------------
# Parameters combination 1 of 6
# params:  {'n_factors': 5, 'n_epochs': 100, 'reg_pu': 0.01, 'reg_qi': 0.01}
# ------------
# Mean MAE : 1.4039
# Mean RMSE: 1.6115
# Mean FCP : 0.6752
# ------------
# ------------
# Parameters combination 2 of 6
# params:  {'n_factors': 10, 'n_epochs': 100, 'reg_pu': 0.01, 'reg_qi': 0.01}
# ------------
# Mean MAE : 0.9021
# Mean RMSE: 1.1140
# Mean FCP : 0.6585
# ------------
# ------------
# Parameters combination 3 of 6
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.01, 'reg_qi': 0.01}
# ------------
# Mean MAE : 0.8228
# Mean RMSE: 1.0722
# Mean FCP : 0.6541
# ------------
# ------------
# Parameters combination 4 of 6
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.01, 'reg_qi': 0.01}
# ------------
# Mean MAE : 0.9105
# Mean RMSE: 1.1996
# Mean FCP : 0.6340
# ------------
# ------------
# Parameters combination 5 of 6
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.01, 'reg_qi': 0.01}
# ------------
# Mean MAE : 1.0093
# Mean RMSE: 1.3203
# Mean FCP : 0.5927
# ------------
# ------------
# Parameters combination 6 of 6
# params:  {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0.01, 'reg_qi': 0.01}
# ------------
# Mean MAE : 1.0822
# Mean RMSE: 1.4035
# Mean FCP : 0.5589
# ------------
# end time :  1509638822
# regularization :  0.005
# start time :  1509638822
# [{'n_factors': 5, 'n_epochs': 100, 'reg_pu': 0.005, 'reg_qi': 0.005}, {'n_factors': 10, 'n_epochs': 100, 'reg_pu': 0.005, 'reg_qi': 0.005}, {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.005, 'reg_qi': 0.005}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.005, 'reg_qi': 0.005}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.005, 'reg_qi': 0.005}, {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0.005, 'reg_qi': 0.005}]
# ------------
# Parameters combination 1 of 6
# params:  {'n_factors': 5, 'n_epochs': 100, 'reg_pu': 0.005, 'reg_qi': 0.005}
# ------------
# Mean MAE : 1.7026
# Mean RMSE: 1.9140
# Mean FCP : 0.6686
# ------------
# ------------
# Parameters combination 2 of 6
# params:  {'n_factors': 10, 'n_epochs': 100, 'reg_pu': 0.005, 'reg_qi': 0.005}
# ------------
# Mean MAE : 0.9779
# Mean RMSE: 1.1902
# Mean FCP : 0.6589
# ------------
# ------------
# Parameters combination 3 of 6
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.005, 'reg_qi': 0.005}
# ------------
# Mean MAE : 0.8357
# Mean RMSE: 1.0955
# Mean FCP : 0.6533
# ------------
# ------------
# Parameters combination 4 of 6
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.005, 'reg_qi': 0.005}
# ------------
# Mean MAE : 1.0073
# Mean RMSE: 1.3198
# Mean FCP : 0.5962
# ------------
# ------------
# Parameters combination 5 of 6
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.005, 'reg_qi': 0.005}
# ------------
# Mean MAE : 1.1701
# Mean RMSE: 1.5031
# Mean FCP : 0.4909
# ------------
# ------------
# Parameters combination 6 of 6
# params:  {'n_factors': 30, 'n_epochs': 100, 'reg_pu': 0.005, 'reg_qi': 0.005}
# ------------
# Mean MAE : 1.2542
# Mean RMSE: 1.5967
# Mean FCP : 0.4189
# ------------
# end time :  1509639050

# %% [markdown]
# vary the number of factors and regularization for the user and item vectors
# the best solutions are obtained for number of factors close to 20 and with regularization of 0.1

# %%
for reg in res_tune:
    c = 0
    print("regularization : ", reg)
    s = ""
    for i in res_tune[reg]['RMSE']:
        s+=str(latent_factors[c])+"||"+str(i)+"   "
        c+=1
    print(s)
# Out:
# regularization :  0.5
# 5||1.07271064851   10||1.07270884096   15||1.07270931582   20||1.07271214409   25||1.07271186057   30||1.07271345796
# regularization :  0.2
# 5||0.964481732192   10||0.960037586959   15||0.956822702207   20||0.956545037179   25||0.956869048284   30||0.956324455172
# regularization :  0.1
# 5||0.955844858224   10||0.952624763697   15||0.951253673568   20||0.950019273807   25||0.945821494002   30||0.945462901898
# regularization :  0.05
# 5||0.985925740406   10||0.98539991551   15||0.985536284856   20||0.984885433828   25||0.9815093813   30||0.978900764633
# regularization :  0.02
# 5||1.2208449747   10||1.04369924497   15||1.03583439752   20||1.07286084228   25||1.10262809749   30||1.1324891287
# regularization :  0.01
# 5||1.61152718343   10||1.11401453898   15||1.07218293294   20||1.19959027659   25||1.32032438757   30||1.40348216765
# regularization :  0.005
# 5||1.91400284988   10||1.19015833846   15||1.09552698668   20||1.31976364152   25||1.50313258803   30||1.5966544425

# %%
res_tune = {}
latent_factors = [15,20,25]
regularizations = [0.2,0.1,0.05,0.02]
learn_bias = [0.02,0.01,0.005,0.002,0.001]
for regularization in regularizations:
    res_tune[regularization] = {}
    for lb in learn_bias:
        print("regularization : ", regularization, " bias : ", lb)
        print("start time : ", int(time.time()))
        param_grid = {'n_factors': latent_factors, 'n_epochs': [100], 'reg_pu': [regularization], 'reg_qi': [regularization], 
                      'lr_bu': [lb], 'lr_bi': [lb], 'reg_bu': [regularization], 'reg_bi': [regularization]}
        grid_search = GridSearch(pa.matrix_factorization.NMF, param_grid=param_grid, measures=['MAE', 'RMSE', 'FCP'])
        grid_search.evaluate(dataset)
        print("end time : ", int(time.time()))
        res_tune[regularization][lb] = grid_search.cv_results
pickle.dump(res_tune, open("nmf_result2","wb"))
# Out:
# regularization :  0.2  bias :  0.02
# start time :  1509640330
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.2, 'reg_bi': 0.2}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.2, 'reg_bi': 0.2}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.2, 'reg_bi': 0.2}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7700
# Mean RMSE: 0.9580
# Mean FCP : 0.7019
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7691
# Mean RMSE: 0.9568
# Mean FCP : 0.7024
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7692
# Mean RMSE: 0.9570
# Mean FCP : 0.7031
# ------------
# end time :  1509640436
# regularization :  0.2  bias :  0.01
# start time :  1509640436
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.2, 'reg_bi': 0.2}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.2, 'reg_bi': 0.2}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.2, 'reg_bi': 0.2}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7691
# Mean RMSE: 0.9571
# Mean FCP : 0.7028
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7694
# Mean RMSE: 0.9572
# Mean FCP : 0.7019
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7690
# Mean RMSE: 0.9566
# Mean FCP : 0.7041
# ------------
# end time :  1509640542
# regularization :  0.2  bias :  0.005
# start time :  1509640542
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.2, 'reg_bi': 0.2}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.2, 'reg_bi': 0.2}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.2, 'reg_bi': 0.2}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7699
# Mean RMSE: 0.9579
# Mean FCP : 0.7021
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7690
# Mean RMSE: 0.9567
# Mean FCP : 0.7030
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7688
# Mean RMSE: 0.9564
# Mean FCP : 0.7039
# ------------
# end time :  1509640647
# regularization :  0.2  bias :  0.002
# start time :  1509640647
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.2, 'reg_bi': 0.2}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.2, 'reg_bi': 0.2}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.2, 'reg_bi': 0.2}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7688
# Mean RMSE: 0.9566
# Mean FCP : 0.7035
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7693
# Mean RMSE: 0.9571
# Mean FCP : 0.7023
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7685
# Mean RMSE: 0.9559
# Mean FCP : 0.7032
# ------------
# end time :  1509640753
# regularization :  0.2  bias :  0.001
# start time :  1509640753
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.2, 'reg_bi': 0.2}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.2, 'reg_bi': 0.2}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.2, 'reg_bi': 0.2}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7694
# Mean RMSE: 0.9573
# Mean FCP : 0.7033
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7688
# Mean RMSE: 0.9566
# Mean FCP : 0.7025
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.2, 'reg_qi': 0.2, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.2, 'reg_bi': 0.2}
# ------------
# Mean MAE : 0.7691
# Mean RMSE: 0.9567
# Mean FCP : 0.7026
# ------------
# end time :  1509640858
# regularization :  0.1  bias :  0.02
# start time :  1509640858
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.1, 'reg_bi': 0.1}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.1, 'reg_bi': 0.1}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.1, 'reg_bi': 0.1}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7545
# Mean RMSE: 0.9523
# Mean FCP : 0.6997
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7537
# Mean RMSE: 0.9501
# Mean FCP : 0.7023
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7520
# Mean RMSE: 0.9483
# Mean FCP : 0.7029
# ------------
# end time :  1509640965
# regularization :  0.1  bias :  0.01
# start time :  1509640965
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.1, 'reg_bi': 0.1}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.1, 'reg_bi': 0.1}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.1, 'reg_bi': 0.1}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7550
# Mean RMSE: 0.9523
# Mean FCP : 0.6989
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7531
# Mean RMSE: 0.9503
# Mean FCP : 0.7026
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7525
# Mean RMSE: 0.9488
# Mean FCP : 0.7018
# ------------
# end time :  1509641074
# regularization :  0.1  bias :  0.005
# start time :  1509641074
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.1, 'reg_bi': 0.1}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.1, 'reg_bi': 0.1}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.1, 'reg_bi': 0.1}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7540
# Mean RMSE: 0.9517
# Mean FCP : 0.6989
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7546
# Mean RMSE: 0.9509
# Mean FCP : 0.7000
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7508
# Mean RMSE: 0.9476
# Mean FCP : 0.7044
# ------------
# end time :  1509641180
# regularization :  0.1  bias :  0.002
# start time :  1509641180
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.1, 'reg_bi': 0.1}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.1, 'reg_bi': 0.1}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.1, 'reg_bi': 0.1}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7552
# Mean RMSE: 0.9527
# Mean FCP : 0.6999
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7539
# Mean RMSE: 0.9513
# Mean FCP : 0.7012
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7514
# Mean RMSE: 0.9472
# Mean FCP : 0.7033
# ------------
# end time :  1509641286
# regularization :  0.1  bias :  0.001
# start time :  1509641286
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.1, 'reg_bi': 0.1}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.1, 'reg_bi': 0.1}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.1, 'reg_bi': 0.1}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7544
# Mean RMSE: 0.9517
# Mean FCP : 0.6983
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7531
# Mean RMSE: 0.9497
# Mean FCP : 0.7036
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.1, 'reg_qi': 0.1, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.1, 'reg_bi': 0.1}
# ------------
# Mean MAE : 0.7519
# Mean RMSE: 0.9478
# Mean FCP : 0.7014
# ------------
# end time :  1509641391
# regularization :  0.05  bias :  0.02
# start time :  1509641391
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.05, 'reg_bi': 0.05}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.05, 'reg_bi': 0.05}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.05, 'reg_bi': 0.05}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7726
# Mean RMSE: 0.9847
# Mean FCP : 0.6806
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7704
# Mean RMSE: 0.9835
# Mean FCP : 0.6822
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7694
# Mean RMSE: 0.9835
# Mean FCP : 0.6812
# ------------
# end time :  1509641497
# regularization :  0.05  bias :  0.01
# start time :  1509641497
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.05, 'reg_bi': 0.05}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.05, 'reg_bi': 0.05}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.05, 'reg_bi': 0.05}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7714
# Mean RMSE: 0.9835
# Mean FCP : 0.6835
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7704
# Mean RMSE: 0.9845
# Mean FCP : 0.6814
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7670
# Mean RMSE: 0.9810
# Mean FCP : 0.6819
# ------------
# end time :  1509641603
# regularization :  0.05  bias :  0.005
# start time :  1509641603
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.05, 'reg_bi': 0.05}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.05, 'reg_bi': 0.05}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.05, 'reg_bi': 0.05}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7728
# Mean RMSE: 0.9861
# Mean FCP : 0.6843
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7700
# Mean RMSE: 0.9831
# Mean FCP : 0.6830
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7689
# Mean RMSE: 0.9823
# Mean FCP : 0.6824
# ------------
# end time :  1509641709
# regularization :  0.05  bias :  0.002
# start time :  1509641709
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.05, 'reg_bi': 0.05}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.05, 'reg_bi': 0.05}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.05, 'reg_bi': 0.05}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7706
# Mean RMSE: 0.9846
# Mean FCP : 0.6816
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7698
# Mean RMSE: 0.9843
# Mean FCP : 0.6827
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7712
# Mean RMSE: 0.9857
# Mean FCP : 0.6789
# ------------
# end time :  1509641815
# regularization :  0.05  bias :  0.001
# start time :  1509641815
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.05, 'reg_bi': 0.05}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.05, 'reg_bi': 0.05}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.05, 'reg_bi': 0.05}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7716
# Mean RMSE: 0.9857
# Mean FCP : 0.6828
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7684
# Mean RMSE: 0.9824
# Mean FCP : 0.6831
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.05, 'reg_qi': 0.05, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.05, 'reg_bi': 0.05}
# ------------
# Mean MAE : 0.7671
# Mean RMSE: 0.9796
# Mean FCP : 0.6848
# ------------
# end time :  1509641921
# regularization :  0.02  bias :  0.02
# start time :  1509641921
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.02, 'reg_bi': 0.02}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.02, 'reg_bi': 0.02}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.02, 'reg_bi': 0.02}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8013
# Mean RMSE: 1.0361
# Mean FCP : 0.6619
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8178
# Mean RMSE: 1.0709
# Mean FCP : 0.6599
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.02, 'lr_bi': 0.02, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8408
# Mean RMSE: 1.1035
# Mean FCP : 0.6588
# ------------
# end time :  1509642026
# regularization :  0.02  bias :  0.01
# start time :  1509642026
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.02, 'reg_bi': 0.02}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.02, 'reg_bi': 0.02}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.02, 'reg_bi': 0.02}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8012
# Mean RMSE: 1.0359
# Mean FCP : 0.6646
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8184
# Mean RMSE: 1.0693
# Mean FCP : 0.6623
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.01, 'lr_bi': 0.01, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8446
# Mean RMSE: 1.1089
# Mean FCP : 0.6557
# ------------
# end time :  1509642133
# regularization :  0.02  bias :  0.005
# start time :  1509642133
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.02, 'reg_bi': 0.02}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.02, 'reg_bi': 0.02}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.02, 'reg_bi': 0.02}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8031
# Mean RMSE: 1.0393
# Mean FCP : 0.6629
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8177
# Mean RMSE: 1.0698
# Mean FCP : 0.6619
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.005, 'lr_bi': 0.005, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8400
# Mean RMSE: 1.1022
# Mean FCP : 0.6562
# ------------
# end time :  1509642239
# regularization :  0.02  bias :  0.002
# start time :  1509642239
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.02, 'reg_bi': 0.02}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.02, 'reg_bi': 0.02}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.02, 'reg_bi': 0.02}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8010
# Mean RMSE: 1.0351
# Mean FCP : 0.6644
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8165
# Mean RMSE: 1.0680
# Mean FCP : 0.6612
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.002, 'lr_bi': 0.002, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8436
# Mean RMSE: 1.1086
# Mean FCP : 0.6535
# ------------
# end time :  1509642347
# regularization :  0.02  bias :  0.001
# start time :  1509642347
# [{'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.02, 'reg_bi': 0.02}, {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.02, 'reg_bi': 0.02}, {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.02, 'reg_bi': 0.02}]
# ------------
# Parameters combination 1 of 3
# params:  {'n_factors': 15, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8024
# Mean RMSE: 1.0382
# Mean FCP : 0.6623
# ------------
# ------------
# Parameters combination 2 of 3
# params:  {'n_factors': 20, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8187
# Mean RMSE: 1.0720
# Mean FCP : 0.6611
# ------------
# ------------
# Parameters combination 3 of 3
# params:  {'n_factors': 25, 'n_epochs': 100, 'reg_pu': 0.02, 'reg_qi': 0.02, 'lr_bu': 0.001, 'lr_bi': 0.001, 'reg_bu': 0.02, 'reg_bi': 0.02}
# ------------
# Mean MAE : 0.8398
# Mean RMSE: 1.1041
# Mean FCP : 0.6594
# ------------
# end time :  1509642453

# %% [markdown]
# for a biased version vary the number of factors and regularization close in a range close to optimal solution and vary the learning rate for the bias

# %%
for reg in res_tune:
    for bias in res_tune[reg]:
        c = 0
        print("regularization : ", reg, " bias : ", bias)
        s = ""
        for i in res_tune[reg][bias]['RMSE']:
            s+=str(latent_factors[c])+"||"+str(i)+"   "
            c+=1
        print(s)
# Out:
# regularization :  0.2  bias :  0.02
# 15||0.957955886225   20||0.956801639138   25||0.956965052735
# regularization :  0.2  bias :  0.01
# 15||0.957088244361   20||0.957191720697   25||0.956629829629
# regularization :  0.2  bias :  0.005
# 15||0.957868404408   20||0.956749298616   25||0.956374413264
# regularization :  0.2  bias :  0.002
# 15||0.956646400892   20||0.957080635227   25||0.955929301294
# regularization :  0.2  bias :  0.001
# 15||0.95726915137   20||0.95660908118   25||0.956713608124
# regularization :  0.1  bias :  0.02
# 15||0.952305422938   20||0.950052743508   25||0.948310202591
# regularization :  0.1  bias :  0.01
# 15||0.952300623538   20||0.950300946018   25||0.948769506117
# regularization :  0.1  bias :  0.005
# 15||0.951659542136   20||0.95090190507   25||0.947646116169
# regularization :  0.1  bias :  0.002
# 15||0.952707252012   20||0.951264994958   25||0.947228744207
# regularization :  0.1  bias :  0.001
# 15||0.951696110829   20||0.949736989011   25||0.947766130909
# regularization :  0.05  bias :  0.02
# 15||0.984660683053   20||0.983498053494   25||0.983460529185
# regularization :  0.05  bias :  0.01
# 15||0.98346298291   20||0.984529517524   25||0.981017161838
# regularization :  0.05  bias :  0.005
# 15||0.986120242358   20||0.983130966011   25||0.982259787785
# regularization :  0.05  bias :  0.002
# 15||0.984612069336   20||0.98432567531   25||0.985711123548
# regularization :  0.05  bias :  0.001
# 15||0.985693375086   20||0.982384807938   25||0.979621763926
# regularization :  0.02  bias :  0.02
# 15||1.03606469067   20||1.07090108358   25||1.10351096488
# regularization :  0.02  bias :  0.01
# 15||1.03592364245   20||1.06925097862   25||1.10885034486
# regularization :  0.02  bias :  0.005
# 15||1.03933155339   20||1.06983315318   25||1.10222538025
# regularization :  0.02  bias :  0.002
# 15||1.03511898147   20||1.06802010954   25||1.10856636437
# regularization :  0.02  bias :  0.001
# 15||1.03818905059   20||1.07195726415   25||1.10405266855

# %% [markdown]
# the best solution is obtained for the model with the parameters
# number of factors = 20
# regularization = 0.1
# and learning rate for bias = 0.001
# not to learn the model with these parameters

# %%
trainset = dataset.build_full_trainset()
algo = pa.matrix_factorization.NMF(n_factors=20, n_epochs=100,reg_pu=0.1, reg_qi=0.1, reg_bu=0.1, reg_bi=0.1, lr_bu=0.001, lr_bi=0.001)
algo.train(trainset)
testset = dataset.construct_testset(B_raw_ratings)
predictions = algo.test(testset)
print('Unbiased accuracy on B,', accuracy.rmse(predictions))
accuracy.rmse(predictions)
accuracy.mae(predictions)
accuracy.fcp(predictions)
dump.dump('./nmf_algo',predictions,algo)
# Out:
# RMSE: 0.9384
# Unbiased accuracy on B, 0.938448606268
# RMSE: 0.9384
# MAE:  0.7443
# FCP:  0.7140
