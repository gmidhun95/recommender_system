# %%
import pandas as pd
from surprise import prediction_algorithms as pa
from surprise import Dataset, Reader, GridSearch, accuracy
from surprise import evaluate, print_perf
import time,random
from collections import defaultdict


def precision_recall_at_k(predictions, k=10, threshold=3.5):
    '''Return precision and recall at k metrics for each user.'''
    # First map the predictions to each user.
    user_est_true = defaultdict(list)
    for uid, _, true_r, est, _ in predictions:
        user_est_true[uid].append((est, true_r))
    precisions = dict()
    recalls = dict()
    for uid, user_ratings in user_est_true.items():
        # Sort user ratings by estimated value
        user_ratings.sort(key=lambda x: x[0], reverse=True)
        # Number of relevant items
        n_rel = sum((true_r >= threshold) for (_, true_r) in user_ratings)
        # Number of recommended items in top k
        n_rec_k = sum((est >= threshold) for (est, _) in user_ratings[:k])
        # Number of relevant and recommended items in top k
        n_rel_and_rec_k = sum(((true_r >= threshold) and (est >= threshold))
                              for (est, true_r) in user_ratings[:k])
        # Precision@K: Proportion of recommended items that are relevant
        precisions[uid] = n_rel_and_rec_k / n_rec_k if n_rec_k != 0 else 1
        # Recall@K: Proportion of relevant items that are recommended
        recalls[uid] = n_rel_and_rec_k / n_rel if n_rel != 0 else 1
    return precisions, recalls

one_hundred_k_data = pd.read_csv('./ml-100k/data.csv')
two_hundred_fifty_data = pd.read_csv("ratingsNew_250k.csv")
five_hundred_data = pd.read_csv("ratingsNew_500k.csv")
seven_hundred_fifty_data = pd.read_csv("ratingsNew_750k.csv")
one_million_data = pd.read_csv("./movielens_1M/ratings.csv")

datasets = [one_hundred_k_data, two_hundred_fifty_data, five_hundred_data, seven_hundred_fifty_data, one_million_data]
datasets_names = ["100k", "250k", "500k", "750k", "1M"]
surprise_datasets = []

for each_dataset in datasets:
    df = pd.DataFrame(each_dataset)
    df.drop('timestamp', axis=1, inplace=True)
    reader = Reader(rating_scale=(1, 5))
    surprise_datasets.append(Dataset.load_from_df(df[['userId', 'movieId', 'rating']], reader))


param_grid = {'n_factors': [80,100,120,140,160], 'n_epochs': [50], 'reg_all': [0.1,0.05,0.02,0.01], 'lr_all': [0.005,0.002]}
grid_search = GridSearch(pa.matrix_factorization.SVD, param_grid=param_grid, measures=['MAE', 'RMSE', 'FCP'])

results_dict = {"Dataset": [], "Average_Running_Time": [], "RMSE": [], "MAE": [], "Precision": [], "Recall": [], "Running_Time": []}

for i in range(len(surprise_datasets)):
    
    dataset = surprise_datasets[i]
    raw_ratings = surprise_datasets[i].raw_ratings
    random.shuffle(raw_ratings)
    threshold = int(.8 * len(raw_ratings))
    A_raw_ratings = raw_ratings[:threshold]
    B_raw_ratings = raw_ratings[threshold:]
    dataset.raw_ratings = A_raw_ratings
    dataset.split(n_folds=5)
    
    start_time = int(time.time())
    grid_search.evaluate(dataset)
    end_time = int(time.time())
    time_taken = (end_time-start_time)/40.0
    
    best_score = grid_search.best_score["RMSE"]
    best_params = grid_search.best_params["RMSE"]
    print best_score,best_params
    
    start_time = int(time.time())
    trainset = dataset.build_full_trainset()
    algo = pa.matrix_factorization.SVD(n_factors=best_params['n_factors'], n_epochs=50, biased=True, 
                                       reg_all=best_params['reg_all'], lr_all=best_params['lr_all'])
    algo.train(trainset)
    end_time = int(time.time())
    running_time = end_time-start_time
    
    testset = dataset.construct_testset(B_raw_ratings)
    predictions = algo.test(testset)
    
    rmse = accuracy.rmse(predictions)
    mae = accuracy.mae(predictions)
    precisions, recalls = precision_recall_at_k(predictions=predictions, k=10, threshold=3)
    precision_percent = (sum(prec for prec in precisions.values()) / float(len(precisions)))
    recall_percent = (sum(rec for rec in recalls.values()) / float(len(recalls)))
    print "Precision, Recall: ", precision_percent, recall_percent
    
    
    results_dict["Dataset"].append(datasets_names[i])
    results_dict["Average_Running_Time"].append(time_taken)
    results_dict["RMSE"].append(rmse)
    results_dict["MAE"].append(mae)
    results_dict["Precision"].append(precision_percent)
    results_dict["Recall"].append(recall_percent)
    results_dict["Running_Time"].append(running_time)
    print "Average RMSE: ", rmse
    print "Average MAE: ", mae
    print "Average Precision: ", precision_percent
    print "Average Recall: ", recall_percent
    print "Time Difference: ", running_time
    
results_df = pd.DataFrame(results_dict)
results_df.to_csv("scale_svd_results.csv")
# Out:
# [{'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 100, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 120, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 140, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 160, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 100, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 120, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 140, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 160, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 100, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 120, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 140, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 160, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 100, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 120, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 140, 'n_epochs': 50}, {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 160, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 100, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 120, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 140, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 160, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 100, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 120, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 140, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 160, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 100, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 120, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 140, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 160, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 80, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 100, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 120, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 140, 'n_epochs': 50}, {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 160, 'n_epochs': 50}]
# ------------
# Parameters combination 1 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7305
# Mean RMSE: 0.9230
# Mean FCP : 0.7072
# ------------
# ------------
# Parameters combination 2 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7300
# Mean RMSE: 0.9220
# Mean FCP : 0.7081
# ------------
# ------------
# Parameters combination 3 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7302
# Mean RMSE: 0.9223
# Mean FCP : 0.7087
# ------------
# ------------
# Parameters combination 4 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7299
# Mean RMSE: 0.9218
# Mean FCP : 0.7085
# ------------
# ------------
# Parameters combination 5 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7299
# Mean RMSE: 0.9218
# Mean FCP : 0.7079
# ------------
# ------------
# Parameters combination 6 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7362
# Mean RMSE: 0.9341
# Mean FCP : 0.6974
# ------------
# ------------
# Parameters combination 7 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7367
# Mean RMSE: 0.9349
# Mean FCP : 0.6952
# ------------
# ------------
# Parameters combination 8 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7365
# Mean RMSE: 0.9335
# Mean FCP : 0.6971
# ------------
# ------------
# Parameters combination 9 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7365
# Mean RMSE: 0.9328
# Mean FCP : 0.6983
# ------------
# ------------
# Parameters combination 10 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7370
# Mean RMSE: 0.9337
# Mean FCP : 0.6957
# ------------
# ------------
# Parameters combination 11 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7637
# Mean RMSE: 0.9717
# Mean FCP : 0.6725
# ------------
# ------------
# Parameters combination 12 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7616
# Mean RMSE: 0.9685
# Mean FCP : 0.6747
# ------------
# ------------
# Parameters combination 13 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7652
# Mean RMSE: 0.9724
# Mean FCP : 0.6687
# ------------
# ------------
# Parameters combination 14 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7618
# Mean RMSE: 0.9665
# Mean FCP : 0.6745
# ------------
# ------------
# Parameters combination 15 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7599
# Mean RMSE: 0.9636
# Mean FCP : 0.6737
# ------------
# ------------
# Parameters combination 16 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7848
# Mean RMSE: 1.0017
# Mean FCP : 0.6583
# ------------
# ------------
# Parameters combination 17 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7821
# Mean RMSE: 0.9954
# Mean FCP : 0.6600
# ------------
# ------------
# Parameters combination 18 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7784
# Mean RMSE: 0.9900
# Mean FCP : 0.6608
# ------------
# ------------
# Parameters combination 19 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7787
# Mean RMSE: 0.9893
# Mean FCP : 0.6574
# ------------
# ------------
# Parameters combination 20 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7742
# Mean RMSE: 0.9857
# Mean FCP : 0.6628
# ------------
# ------------
# Parameters combination 21 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7467
# Mean RMSE: 0.9415
# Mean FCP : 0.6929
# ------------
# ------------
# Parameters combination 22 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7459
# Mean RMSE: 0.9405
# Mean FCP : 0.6935
# ------------
# ------------
# Parameters combination 23 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7460
# Mean RMSE: 0.9406
# Mean FCP : 0.6939
# ------------
# ------------
# Parameters combination 24 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7461
# Mean RMSE: 0.9406
# Mean FCP : 0.6946
# ------------
# ------------
# Parameters combination 25 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7456
# Mean RMSE: 0.9400
# Mean FCP : 0.6949
# ------------
# ------------
# Parameters combination 26 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7433
# Mean RMSE: 0.9392
# Mean FCP : 0.6925
# ------------
# ------------
# Parameters combination 27 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7428
# Mean RMSE: 0.9389
# Mean FCP : 0.6932
# ------------
# ------------
# Parameters combination 28 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7436
# Mean RMSE: 0.9396
# Mean FCP : 0.6937
# ------------
# ------------
# Parameters combination 29 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7443
# Mean RMSE: 0.9409
# Mean FCP : 0.6897
# ------------
# ------------
# Parameters combination 30 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7431
# Mean RMSE: 0.9388
# Mean FCP : 0.6934
# ------------
# ------------
# Parameters combination 31 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7441
# Mean RMSE: 0.9425
# Mean FCP : 0.6862
# ------------
# ------------
# Parameters combination 32 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7452
# Mean RMSE: 0.9441
# Mean FCP : 0.6862
# ------------
# ------------
# Parameters combination 33 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7469
# Mean RMSE: 0.9454
# Mean FCP : 0.6881
# ------------
# ------------
# Parameters combination 34 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7463
# Mean RMSE: 0.9453
# Mean FCP : 0.6862
# ------------
# ------------
# Parameters combination 35 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7498
# Mean RMSE: 0.9487
# Mean FCP : 0.6858
# ------------
# ------------
# Parameters combination 36 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7484
# Mean RMSE: 0.9482
# Mean FCP : 0.6830
# ------------
# ------------
# Parameters combination 37 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7487
# Mean RMSE: 0.9496
# Mean FCP : 0.6819
# ------------
# ------------
# Parameters combination 38 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7511
# Mean RMSE: 0.9516
# Mean FCP : 0.6812
# ------------
# ------------
# Parameters combination 39 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7529
# Mean RMSE: 0.9530
# Mean FCP : 0.6782
# ------------
# ------------
# Parameters combination 40 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7523
# Mean RMSE: 0.9525
# Mean FCP : 0.6785
# ------------
# 0.921805809099 {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 140, 'n_epochs': 50}
# RMSE: 0.9215
# MAE:  0.7279
# Precision, Recall:  0.605095541401 0.299363057325
# Average RMSE:  0.92146408461
# Average MAE:  0.727877155096
# Average Precision:  0.605095541401
# Average Recall:  0.299363057325
# Time Difference:  11
# ------------
# Parameters combination 1 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7068
# Mean RMSE: 0.8923
# Mean FCP : 0.7219
# ------------
# ------------
# Parameters combination 2 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7060
# Mean RMSE: 0.8915
# Mean FCP : 0.7224
# ------------
# ------------
# Parameters combination 3 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7058
# Mean RMSE: 0.8914
# Mean FCP : 0.7233
# ------------
# ------------
# Parameters combination 4 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7058
# Mean RMSE: 0.8911
# Mean FCP : 0.7231
# ------------
# ------------
# Parameters combination 5 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7059
# Mean RMSE: 0.8912
# Mean FCP : 0.7236
# ------------
# ------------
# Parameters combination 6 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7061
# Mean RMSE: 0.8967
# Mean FCP : 0.7169
# ------------
# ------------
# Parameters combination 7 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7055
# Mean RMSE: 0.8959
# Mean FCP : 0.7173
# ------------
# ------------
# Parameters combination 8 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7059
# Mean RMSE: 0.8959
# Mean FCP : 0.7177
# ------------
# ------------
# Parameters combination 9 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7051
# Mean RMSE: 0.8948
# Mean FCP : 0.7190
# ------------
# ------------
# Parameters combination 10 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7059
# Mean RMSE: 0.8956
# Mean FCP : 0.7177
# ------------
# ------------
# Parameters combination 11 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7391
# Mean RMSE: 0.9452
# Mean FCP : 0.6885
# ------------
# ------------
# Parameters combination 12 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7389
# Mean RMSE: 0.9436
# Mean FCP : 0.6859
# ------------
# ------------
# Parameters combination 13 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7376
# Mean RMSE: 0.9401
# Mean FCP : 0.6889
# ------------
# ------------
# Parameters combination 14 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7350
# Mean RMSE: 0.9371
# Mean FCP : 0.6908
# ------------
# ------------
# Parameters combination 15 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7338
# Mean RMSE: 0.9346
# Mean FCP : 0.6919
# ------------
# ------------
# Parameters combination 16 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7655
# Mean RMSE: 0.9813
# Mean FCP : 0.6703
# ------------
# ------------
# Parameters combination 17 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7639
# Mean RMSE: 0.9774
# Mean FCP : 0.6709
# ------------
# ------------
# Parameters combination 18 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7609
# Mean RMSE: 0.9737
# Mean FCP : 0.6719
# ------------
# ------------
# Parameters combination 19 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7600
# Mean RMSE: 0.9705
# Mean FCP : 0.6724
# ------------
# ------------
# Parameters combination 20 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7581
# Mean RMSE: 0.9678
# Mean FCP : 0.6730
# ------------
# ------------
# Parameters combination 21 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7234
# Mean RMSE: 0.9120
# Mean FCP : 0.7103
# ------------
# ------------
# Parameters combination 22 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7230
# Mean RMSE: 0.9115
# Mean FCP : 0.7109
# ------------
# ------------
# Parameters combination 23 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7228
# Mean RMSE: 0.9112
# Mean FCP : 0.7113
# ------------
# ------------
# Parameters combination 24 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7224
# Mean RMSE: 0.9108
# Mean FCP : 0.7113
# ------------
# ------------
# Parameters combination 25 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7222
# Mean RMSE: 0.9105
# Mean FCP : 0.7120
# ------------
# ------------
# Parameters combination 26 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7161
# Mean RMSE: 0.9051
# Mean FCP : 0.7135
# ------------
# ------------
# Parameters combination 27 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7154
# Mean RMSE: 0.9044
# Mean FCP : 0.7149
# ------------
# ------------
# Parameters combination 28 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7153
# Mean RMSE: 0.9046
# Mean FCP : 0.7143
# ------------
# ------------
# Parameters combination 29 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7151
# Mean RMSE: 0.9041
# Mean FCP : 0.7157
# ------------
# ------------
# Parameters combination 30 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7153
# Mean RMSE: 0.9043
# Mean FCP : 0.7157
# ------------
# ------------
# Parameters combination 31 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7171
# Mean RMSE: 0.9099
# Mean FCP : 0.7076
# ------------
# ------------
# Parameters combination 32 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7186
# Mean RMSE: 0.9117
# Mean FCP : 0.7065
# ------------
# ------------
# Parameters combination 33 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7199
# Mean RMSE: 0.9135
# Mean FCP : 0.7051
# ------------
# ------------
# Parameters combination 34 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7198
# Mean RMSE: 0.9133
# Mean FCP : 0.7067
# ------------
# ------------
# Parameters combination 35 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7212
# Mean RMSE: 0.9155
# Mean FCP : 0.7033
# ------------
# ------------
# Parameters combination 36 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7231
# Mean RMSE: 0.9190
# Mean FCP : 0.7001
# ------------
# ------------
# Parameters combination 37 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7246
# Mean RMSE: 0.9208
# Mean FCP : 0.6993
# ------------
# ------------
# Parameters combination 38 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7278
# Mean RMSE: 0.9246
# Mean FCP : 0.6972
# ------------
# ------------
# Parameters combination 39 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7284
# Mean RMSE: 0.9260
# Mean FCP : 0.6954
# ------------
# ------------
# Parameters combination 40 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7308
# Mean RMSE: 0.9281
# Mean FCP : 0.6941
# ------------
# 0.891134131692 {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 140, 'n_epochs': 50}
# RMSE: 0.8774
# MAE:  0.6959
# Precision, Recall:  0.666781056966 0.417638984214
# Average RMSE:  0.877392524612
# Average MAE:  0.695922229633
# Average Precision:  0.666781056966
# Average Recall:  0.417638984214
# Time Difference:  25
# ------------
# Parameters combination 1 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6980
# Mean RMSE: 0.8809
# Mean FCP : 0.7294
# ------------
# ------------
# Parameters combination 2 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6970
# Mean RMSE: 0.8798
# Mean FCP : 0.7301
# ------------
# ------------
# Parameters combination 3 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6968
# Mean RMSE: 0.8795
# Mean FCP : 0.7308
# ------------
# ------------
# Parameters combination 4 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6967
# Mean RMSE: 0.8793
# Mean FCP : 0.7307
# ------------
# ------------
# Parameters combination 5 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6964
# Mean RMSE: 0.8790
# Mean FCP : 0.7311
# ------------
# ------------
# Parameters combination 6 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6906
# Mean RMSE: 0.8773
# Mean FCP : 0.7302
# ------------
# ------------
# Parameters combination 7 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6912
# Mean RMSE: 0.8780
# Mean FCP : 0.7292
# ------------
# ------------
# Parameters combination 8 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6909
# Mean RMSE: 0.8775
# Mean FCP : 0.7309
# ------------
# ------------
# Parameters combination 9 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6910
# Mean RMSE: 0.8770
# Mean FCP : 0.7315
# ------------
# ------------
# Parameters combination 10 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6913
# Mean RMSE: 0.8773
# Mean FCP : 0.7311
# ------------
# ------------
# Parameters combination 11 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7282
# Mean RMSE: 0.9320
# Mean FCP : 0.6980
# ------------
# ------------
# Parameters combination 12 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7287
# Mean RMSE: 0.9321
# Mean FCP : 0.6974
# ------------
# ------------
# Parameters combination 13 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7274
# Mean RMSE: 0.9291
# Mean FCP : 0.6980
# ------------
# ------------
# Parameters combination 14 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7259
# Mean RMSE: 0.9269
# Mean FCP : 0.6992
# ------------
# ------------
# Parameters combination 15 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7248
# Mean RMSE: 0.9241
# Mean FCP : 0.6997
# ------------
# ------------
# Parameters combination 16 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7578
# Mean RMSE: 0.9739
# Mean FCP : 0.6798
# ------------
# ------------
# Parameters combination 17 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7593
# Mean RMSE: 0.9738
# Mean FCP : 0.6787
# ------------
# ------------
# Parameters combination 18 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7589
# Mean RMSE: 0.9717
# Mean FCP : 0.6774
# ------------
# ------------
# Parameters combination 19 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7571
# Mean RMSE: 0.9685
# Mean FCP : 0.6789
# ------------
# ------------
# Parameters combination 20 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7535
# Mean RMSE: 0.9634
# Mean FCP : 0.6798
# ------------
# ------------
# Parameters combination 21 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7159
# Mean RMSE: 0.9022
# Mean FCP : 0.7150
# ------------
# ------------
# Parameters combination 22 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7152
# Mean RMSE: 0.9014
# Mean FCP : 0.7159
# ------------
# ------------
# Parameters combination 23 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7150
# Mean RMSE: 0.9010
# Mean FCP : 0.7165
# ------------
# ------------
# Parameters combination 24 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7142
# Mean RMSE: 0.9002
# Mean FCP : 0.7171
# ------------
# ------------
# Parameters combination 25 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7136
# Mean RMSE: 0.8993
# Mean FCP : 0.7178
# ------------
# ------------
# Parameters combination 26 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7039
# Mean RMSE: 0.8900
# Mean FCP : 0.7244
# ------------
# ------------
# Parameters combination 27 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7031
# Mean RMSE: 0.8891
# Mean FCP : 0.7254
# ------------
# ------------
# Parameters combination 28 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7029
# Mean RMSE: 0.8889
# Mean FCP : 0.7245
# ------------
# ------------
# Parameters combination 29 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7021
# Mean RMSE: 0.8878
# Mean FCP : 0.7265
# ------------
# ------------
# Parameters combination 30 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7024
# Mean RMSE: 0.8884
# Mean FCP : 0.7257
# ------------
# ------------
# Parameters combination 31 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7052
# Mean RMSE: 0.8954
# Mean FCP : 0.7178
# ------------
# ------------
# Parameters combination 32 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7071
# Mean RMSE: 0.8975
# Mean FCP : 0.7161
# ------------
# ------------
# Parameters combination 33 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7078
# Mean RMSE: 0.8987
# Mean FCP : 0.7147
# ------------
# ------------
# Parameters combination 34 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7088
# Mean RMSE: 0.8999
# Mean FCP : 0.7143
# ------------
# ------------
# Parameters combination 35 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7097
# Mean RMSE: 0.9011
# Mean FCP : 0.7141
# ------------
# ------------
# Parameters combination 36 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7133
# Mean RMSE: 0.9081
# Mean FCP : 0.7086
# ------------
# ------------
# Parameters combination 37 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7169
# Mean RMSE: 0.9125
# Mean FCP : 0.7056
# ------------
# ------------
# Parameters combination 38 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7191
# Mean RMSE: 0.9147
# Mean FCP : 0.7040
# ------------
# ------------
# Parameters combination 39 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7206
# Mean RMSE: 0.9172
# Mean FCP : 0.7022
# ------------
# ------------
# Parameters combination 40 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7217
# Mean RMSE: 0.9184
# Mean FCP : 0.7026
# ------------
# 0.877026279797 {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 140, 'n_epochs': 50}
# RMSE: 0.8663
# MAE:  0.6821
# Precision, Recall:  0.673812154696 0.34364640884
# Average RMSE:  0.866320760195
# Average MAE:  0.682079091827
# Average Precision:  0.673812154696
# Average Recall:  0.34364640884
# Time Difference:  51
# ------------
# Parameters combination 1 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6958
# Mean RMSE: 0.8774
# Mean FCP : 0.7357
# ------------
# ------------
# Parameters combination 2 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6952
# Mean RMSE: 0.8767
# Mean FCP : 0.7361
# ------------
# ------------
# Parameters combination 3 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6948
# Mean RMSE: 0.8762
# Mean FCP : 0.7366
# ------------
# ------------
# Parameters combination 4 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6945
# Mean RMSE: 0.8758
# Mean FCP : 0.7370
# ------------
# ------------
# Parameters combination 5 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6942
# Mean RMSE: 0.8754
# Mean FCP : 0.7373
# ------------
# ------------
# Parameters combination 6 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6847
# Mean RMSE: 0.8695
# Mean FCP : 0.7398
# ------------
# ------------
# Parameters combination 7 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6843
# Mean RMSE: 0.8688
# Mean FCP : 0.7410
# ------------
# ------------
# Parameters combination 8 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6845
# Mean RMSE: 0.8686
# Mean FCP : 0.7410
# ------------
# ------------
# Parameters combination 9 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6848
# Mean RMSE: 0.8689
# Mean FCP : 0.7410
# ------------
# ------------
# Parameters combination 10 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6847
# Mean RMSE: 0.8682
# Mean FCP : 0.7418
# ------------
# ------------
# Parameters combination 11 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7206
# Mean RMSE: 0.9228
# Mean FCP : 0.7107
# ------------
# ------------
# Parameters combination 12 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7219
# Mean RMSE: 0.9230
# Mean FCP : 0.7091
# ------------
# ------------
# Parameters combination 13 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7214
# Mean RMSE: 0.9215
# Mean FCP : 0.7091
# ------------
# ------------
# Parameters combination 14 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7205
# Mean RMSE: 0.9192
# Mean FCP : 0.7100
# ------------
# ------------
# Parameters combination 15 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7190
# Mean RMSE: 0.9175
# Mean FCP : 0.7104
# ------------
# ------------
# Parameters combination 16 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7515
# Mean RMSE: 0.9658
# Mean FCP : 0.6926
# ------------
# ------------
# Parameters combination 17 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7538
# Mean RMSE: 0.9679
# Mean FCP : 0.6884
# ------------
# ------------
# Parameters combination 18 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7544
# Mean RMSE: 0.9667
# Mean FCP : 0.6874
# ------------
# ------------
# Parameters combination 19 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7523
# Mean RMSE: 0.9631
# Mean FCP : 0.6895
# ------------
# ------------
# Parameters combination 20 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7521
# Mean RMSE: 0.9618
# Mean FCP : 0.6881
# ------------
# ------------
# Parameters combination 21 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7149
# Mean RMSE: 0.9005
# Mean FCP : 0.7212
# ------------
# ------------
# Parameters combination 22 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7140
# Mean RMSE: 0.8994
# Mean FCP : 0.7222
# ------------
# ------------
# Parameters combination 23 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7136
# Mean RMSE: 0.8988
# Mean FCP : 0.7225
# ------------
# ------------
# Parameters combination 24 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7130
# Mean RMSE: 0.8981
# Mean FCP : 0.7229
# ------------
# ------------
# Parameters combination 25 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7121
# Mean RMSE: 0.8970
# Mean FCP : 0.7238
# ------------
# ------------
# Parameters combination 26 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6993
# Mean RMSE: 0.8838
# Mean FCP : 0.7329
# ------------
# ------------
# Parameters combination 27 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6985
# Mean RMSE: 0.8828
# Mean FCP : 0.7342
# ------------
# ------------
# Parameters combination 28 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6980
# Mean RMSE: 0.8823
# Mean FCP : 0.7347
# ------------
# ------------
# Parameters combination 29 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6973
# Mean RMSE: 0.8816
# Mean FCP : 0.7349
# ------------
# ------------
# Parameters combination 30 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6974
# Mean RMSE: 0.8816
# Mean FCP : 0.7352
# ------------
# ------------
# Parameters combination 31 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7000
# Mean RMSE: 0.8890
# Mean FCP : 0.7269
# ------------
# ------------
# Parameters combination 32 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7009
# Mean RMSE: 0.8901
# Mean FCP : 0.7270
# ------------
# ------------
# Parameters combination 33 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7019
# Mean RMSE: 0.8913
# Mean FCP : 0.7259
# ------------
# ------------
# Parameters combination 34 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7033
# Mean RMSE: 0.8931
# Mean FCP : 0.7243
# ------------
# ------------
# Parameters combination 35 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7040
# Mean RMSE: 0.8938
# Mean FCP : 0.7243
# ------------
# ------------
# Parameters combination 36 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7098
# Mean RMSE: 0.9039
# Mean FCP : 0.7174
# ------------
# ------------
# Parameters combination 37 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7120
# Mean RMSE: 0.9068
# Mean FCP : 0.7149
# ------------
# ------------
# Parameters combination 38 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7142
# Mean RMSE: 0.9097
# Mean FCP : 0.7121
# ------------
# ------------
# Parameters combination 39 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7163
# Mean RMSE: 0.9124
# Mean FCP : 0.7116
# ------------
# ------------
# Parameters combination 40 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7180
# Mean RMSE: 0.9134
# Mean FCP : 0.7106
# ------------
# 0.868248966087 {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 160, 'n_epochs': 50}
# RMSE: 0.8556
# MAE:  0.6731
# Precision, Recall:  0.706050841389 0.294844253491
# Average RMSE:  0.855571972987
# Average MAE:  0.673057660818
# Average Precision:  0.706050841389
# Average Recall:  0.294844253491
# Time Difference:  81
# ------------
# Parameters combination 1 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6957
# Mean RMSE: 0.8781
# Mean FCP : 0.7403
# ------------
# ------------
# Parameters combination 2 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6952
# Mean RMSE: 0.8775
# Mean FCP : 0.7408
# ------------
# ------------
# Parameters combination 3 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6948
# Mean RMSE: 0.8769
# Mean FCP : 0.7411
# ------------
# ------------
# Parameters combination 4 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6944
# Mean RMSE: 0.8765
# Mean FCP : 0.7416
# ------------
# ------------
# Parameters combination 5 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.1, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6942
# Mean RMSE: 0.8762
# Mean FCP : 0.7418
# ------------
# ------------
# Parameters combination 6 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6818
# Mean RMSE: 0.8669
# Mean FCP : 0.7475
# ------------
# ------------
# Parameters combination 7 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6817
# Mean RMSE: 0.8667
# Mean FCP : 0.7475
# ------------
# ------------
# Parameters combination 8 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6817
# Mean RMSE: 0.8662
# Mean FCP : 0.7482
# ------------
# ------------
# Parameters combination 9 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6818
# Mean RMSE: 0.8662
# Mean FCP : 0.7485
# ------------
# ------------
# Parameters combination 10 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6819
# Mean RMSE: 0.8661
# Mean FCP : 0.7486
# ------------
# ------------
# Parameters combination 11 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7183
# Mean RMSE: 0.9212
# Mean FCP : 0.7175
# ------------
# ------------
# Parameters combination 12 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7199
# Mean RMSE: 0.9222
# Mean FCP : 0.7151
# ------------
# ------------
# Parameters combination 13 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7190
# Mean RMSE: 0.9202
# Mean FCP : 0.7165
# ------------
# ------------
# Parameters combination 14 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7176
# Mean RMSE: 0.9176
# Mean FCP : 0.7177
# ------------
# ------------
# Parameters combination 15 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.02, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7169
# Mean RMSE: 0.9164
# Mean FCP : 0.7172
# ------------
# ------------
# Parameters combination 16 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7470
# Mean RMSE: 0.9623
# Mean FCP : 0.7008
# ------------
# ------------
# Parameters combination 17 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7509
# Mean RMSE: 0.9665
# Mean FCP : 0.6972
# ------------
# ------------
# Parameters combination 18 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7537
# Mean RMSE: 0.9678
# Mean FCP : 0.6945
# ------------
# ------------
# Parameters combination 19 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7530
# Mean RMSE: 0.9659
# Mean FCP : 0.6946
# ------------
# ------------
# Parameters combination 20 of 40
# params:  {'lr_all': 0.005, 'reg_all': 0.01, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7517
# Mean RMSE: 0.9635
# Mean FCP : 0.6945
# ------------
# ------------
# Parameters combination 21 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7146
# Mean RMSE: 0.9008
# Mean FCP : 0.7268
# ------------
# ------------
# Parameters combination 22 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7135
# Mean RMSE: 0.8994
# Mean FCP : 0.7278
# ------------
# ------------
# Parameters combination 23 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7129
# Mean RMSE: 0.8988
# Mean FCP : 0.7284
# ------------
# ------------
# Parameters combination 24 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7126
# Mean RMSE: 0.8984
# Mean FCP : 0.7286
# ------------
# ------------
# Parameters combination 25 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.1, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7117
# Mean RMSE: 0.8973
# Mean FCP : 0.7294
# ------------
# ------------
# Parameters combination 26 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6973
# Mean RMSE: 0.8826
# Mean FCP : 0.7390
# ------------
# ------------
# Parameters combination 27 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6961
# Mean RMSE: 0.8811
# Mean FCP : 0.7401
# ------------
# ------------
# Parameters combination 28 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6955
# Mean RMSE: 0.8803
# Mean FCP : 0.7409
# ------------
# ------------
# Parameters combination 29 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6954
# Mean RMSE: 0.8802
# Mean FCP : 0.7412
# ------------
# ------------
# Parameters combination 30 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.05, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6947
# Mean RMSE: 0.8796
# Mean FCP : 0.7415
# ------------
# ------------
# Parameters combination 31 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6978
# Mean RMSE: 0.8875
# Mean FCP : 0.7332
# ------------
# ------------
# Parameters combination 32 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6987
# Mean RMSE: 0.8888
# Mean FCP : 0.7327
# ------------
# ------------
# Parameters combination 33 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.6995
# Mean RMSE: 0.8902
# Mean FCP : 0.7316
# ------------
# ------------
# Parameters combination 34 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7009
# Mean RMSE: 0.8914
# Mean FCP : 0.7314
# ------------
# ------------
# Parameters combination 35 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.02, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7013
# Mean RMSE: 0.8918
# Mean FCP : 0.7311
# ------------
# ------------
# Parameters combination 36 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 80, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7077
# Mean RMSE: 0.9030
# Mean FCP : 0.7232
# ------------
# ------------
# Parameters combination 37 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 100, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7106
# Mean RMSE: 0.9065
# Mean FCP : 0.7212
# ------------
# ------------
# Parameters combination 38 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 120, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7132
# Mean RMSE: 0.9100
# Mean FCP : 0.7189
# ------------
# ------------
# Parameters combination 39 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 140, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7151
# Mean RMSE: 0.9122
# Mean FCP : 0.7175
# ------------
# ------------
# Parameters combination 40 of 40
# params:  {'lr_all': 0.002, 'reg_all': 0.01, 'n_factors': 160, 'n_epochs': 50}
# ------------
# Mean MAE : 0.7169
# Mean RMSE: 0.9144
# Mean FCP : 0.7157
# ------------
# 0.866130842972 {'lr_all': 0.005, 'reg_all': 0.05, 'n_factors': 160, 'n_epochs': 50}
# RMSE: 0.8532
# MAE:  0.6715
# Precision, Recall:  0.701094164456 0.238726790451
# Average RMSE:  0.853174342777
# Average MAE:  0.67153048192
# Average Precision:  0.701094164456
# Average Recall:  0.238726790451
# Time Difference:  107

# %% [markdown]
# run the svd model for different datasets 100K, 250K, 500K, 750K and 1M and output the rmse,mae, precision, recall and runtime for all the datasets
