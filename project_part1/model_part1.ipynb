# %%
import pandas as pd
from surprise import prediction_algorithms as pa
from surprise import Dataset, Reader
from surprise import evaluate, print_perf

# %%
data = pd.read_csv('./movielens_small/ratings.csv')
number_of_rows = len(data)

# %%
for nfolds in [2,3,4,5]:
    reader = Reader(rating_scale=(0.5, 5))
    train_data = Dataset.load_from_df(data[['userId','movieId','rating']], reader)

    algo = pa.matrix_factorization.NMF()

    train_data.split(n_folds=nfolds)

    perf = evaluate(algo, train_data, measures=['RMSE', 'MAE','FCP'])
# Out:
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9838
# MAE:  0.7564
# FCP:  0.6202
# ------------
# Fold 2
# RMSE: 0.9828
# MAE:  0.7551
# FCP:  0.6242
# ------------
# ------------
# Mean RMSE: 0.9833
# Mean MAE : 0.7557
# Mean FCP : 0.6222
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9543
# MAE:  0.7356
# FCP:  0.6323
# ------------
# Fold 2
# RMSE: 0.9631
# MAE:  0.7395
# FCP:  0.6314
# ------------
# Fold 3
# RMSE: 0.9584
# MAE:  0.7376
# FCP:  0.6314
# ------------
# ------------
# Mean RMSE: 0.9586
# Mean MAE : 0.7376
# Mean FCP : 0.6317
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9559
# MAE:  0.7359
# FCP:  0.6339
# ------------
# Fold 2
# RMSE: 0.9566
# MAE:  0.7300
# FCP:  0.6370
# ------------
# Fold 3
# RMSE: 0.9560
# MAE:  0.7337
# FCP:  0.6251
# ------------
# Fold 4
# RMSE: 0.9471
# MAE:  0.7305
# FCP:  0.6339
# ------------
# ------------
# Mean RMSE: 0.9539
# Mean MAE : 0.7325
# Mean FCP : 0.6325
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9531
# MAE:  0.7315
# FCP:  0.6379
# ------------
# Fold 2
# RMSE: 0.9543
# MAE:  0.7312
# FCP:  0.6297
# ------------
# Fold 3
# RMSE: 0.9449
# MAE:  0.7251
# FCP:  0.6432
# ------------
# Fold 4
# RMSE: 0.9378
# MAE:  0.7179
# FCP:  0.6353
# ------------
# Fold 5
# RMSE: 0.9556
# MAE:  0.7349
# FCP:  0.6287
# ------------
# ------------
# Mean RMSE: 0.9491
# Mean MAE : 0.7281
# Mean FCP : 0.6350
# ------------
# ------------

# %%
res_tune = {}
for latent_factors in [5,10,15,20,25,30]:
    res_tune[latent_factors] = {}
    for reg_t in [1,0.5,0.2,0.1,0.05,0.02,0.01]:
        reader = Reader(rating_scale=(0.5, 5))
        train_data = Dataset.load_from_df(data[['userId','movieId','rating']], reader)

        algo = pa.matrix_factorization.NMF(n_factors=latent_factors, n_epochs=100,reg_pu=reg_t, reg_qi=reg_t)

        train_data.split(n_folds=5)

        perf = evaluate(algo, train_data, measures=['RMSE', 'MAE','FCP'])
        
        res_tune[latent_factors][reg_t] = perf
# Out:
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.3377
# MAE:  1.1594
# FCP:  0.6369
# ------------
# Fold 2
# RMSE: 1.3391
# MAE:  1.1616
# FCP:  0.6317
# ------------
# Fold 3
# RMSE: 1.3162
# MAE:  1.1383
# FCP:  0.6282
# ------------
# Fold 4
# RMSE: 1.3256
# MAE:  1.1477
# FCP:  0.6287
# ------------
# Fold 5
# RMSE: 1.3360
# MAE:  1.1555
# FCP:  0.6169
# ------------
# ------------
# Mean RMSE: 1.3309
# Mean MAE : 1.1525
# Mean FCP : 0.6285
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.0387
# MAE:  0.8528
# FCP:  0.6298
# ------------
# Fold 2
# RMSE: 1.0256
# MAE:  0.8400
# FCP:  0.6341
# ------------
# Fold 3
# RMSE: 1.0320
# MAE:  0.8434
# FCP:  0.6304
# ------------
# Fold 4
# RMSE: 1.0333
# MAE:  0.8462
# FCP:  0.6325
# ------------
# Fold 5
# RMSE: 1.0241
# MAE:  0.8379
# FCP:  0.6236
# ------------
# ------------
# Mean RMSE: 1.0307
# Mean MAE : 0.8440
# Mean FCP : 0.6301
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9375
# MAE:  0.7334
# FCP:  0.6421
# ------------
# Fold 2
# RMSE: 0.9398
# MAE:  0.7399
# FCP:  0.6449
# ------------
# Fold 3
# RMSE: 0.9340
# MAE:  0.7317
# FCP:  0.6348
# ------------
# Fold 4
# RMSE: 0.9314
# MAE:  0.7301
# FCP:  0.6449
# ------------
# Fold 5
# RMSE: 0.9248
# MAE:  0.7270
# FCP:  0.6528
# ------------
# ------------
# Mean RMSE: 0.9335
# Mean MAE : 0.7324
# Mean FCP : 0.6439
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9356
# MAE:  0.7233
# FCP:  0.6452
# ------------
# Fold 2
# RMSE: 0.9255
# MAE:  0.7123
# FCP:  0.6479
# ------------
# Fold 3
# RMSE: 0.9509
# MAE:  0.7327
# FCP:  0.6416
# ------------
# Fold 4
# RMSE: 0.9427
# MAE:  0.7306
# FCP:  0.6435
# ------------
# Fold 5
# RMSE: 0.9303
# MAE:  0.7168
# FCP:  0.6376
# ------------
# ------------
# Mean RMSE: 0.9370
# Mean MAE : 0.7231
# Mean FCP : 0.6432
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9671
# MAE:  0.7494
# FCP:  0.6332
# ------------
# Fold 2
# RMSE: 0.9742
# MAE:  0.7535
# FCP:  0.6281
# ------------
# Fold 3
# RMSE: 0.9723
# MAE:  0.7563
# FCP:  0.6346
# ------------
# Fold 4
# RMSE: 0.9686
# MAE:  0.7513
# FCP:  0.6190
# ------------
# Fold 5
# RMSE: 0.9817
# MAE:  0.7620
# FCP:  0.6282
# ------------
# ------------
# Mean RMSE: 0.9728
# Mean MAE : 0.7545
# Mean FCP : 0.6286
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.2148
# MAE:  1.0153
# FCP:  0.6119
# ------------
# Fold 2
# RMSE: 1.2038
# MAE:  1.0063
# FCP:  0.6123
# ------------
# Fold 3
# RMSE: 1.2090
# MAE:  1.0108
# FCP:  0.6134
# ------------
# Fold 4
# RMSE: 1.1995
# MAE:  1.0026
# FCP:  0.6115
# ------------
# Fold 5
# RMSE: 1.2151
# MAE:  1.0189
# FCP:  0.6112
# ------------
# ------------
# Mean RMSE: 1.2085
# Mean MAE : 1.0108
# Mean FCP : 0.6121
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.5834
# MAE:  1.3910
# FCP:  0.5987
# ------------
# Fold 2
# RMSE: 1.5922
# MAE:  1.4006
# FCP:  0.5984
# ------------
# Fold 3
# RMSE: 1.5669
# MAE:  1.3804
# FCP:  0.6100
# ------------
# Fold 4
# RMSE: 1.5718
# MAE:  1.3846
# FCP:  0.6070
# ------------
# Fold 5
# RMSE: 1.6105
# MAE:  1.4222
# FCP:  0.6042
# ------------
# ------------
# Mean RMSE: 1.5850
# Mean MAE : 1.3957
# Mean FCP : 0.6037
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.3351
# MAE:  1.1582
# FCP:  0.6296
# ------------
# Fold 2
# RMSE: 1.3273
# MAE:  1.1495
# FCP:  0.6253
# ------------
# Fold 3
# RMSE: 1.3331
# MAE:  1.1522
# FCP:  0.6252
# ------------
# Fold 4
# RMSE: 1.3356
# MAE:  1.1587
# FCP:  0.6228
# ------------
# Fold 5
# RMSE: 1.3277
# MAE:  1.1495
# FCP:  0.6285
# ------------
# ------------
# Mean RMSE: 1.3317
# Mean MAE : 1.1536
# Mean FCP : 0.6263
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.0327
# MAE:  0.8430
# FCP:  0.6278
# ------------
# Fold 2
# RMSE: 1.0236
# MAE:  0.8408
# FCP:  0.6255
# ------------
# Fold 3
# RMSE: 1.0295
# MAE:  0.8445
# FCP:  0.6373
# ------------
# Fold 4
# RMSE: 1.0328
# MAE:  0.8469
# FCP:  0.6314
# ------------
# Fold 5
# RMSE: 1.0365
# MAE:  0.8453
# FCP:  0.6311
# ------------
# ------------
# Mean RMSE: 1.0310
# Mean MAE : 0.8441
# Mean FCP : 0.6306
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9384
# MAE:  0.7368
# FCP:  0.6534
# ------------
# Fold 2
# RMSE: 0.9253
# MAE:  0.7256
# FCP:  0.6379
# ------------
# Fold 3
# RMSE: 0.9251
# MAE:  0.7266
# FCP:  0.6537
# ------------
# Fold 4
# RMSE: 0.9239
# MAE:  0.7250
# FCP:  0.6465
# ------------
# Fold 5
# RMSE: 0.9301
# MAE:  0.7304
# FCP:  0.6494
# ------------
# ------------
# Mean RMSE: 0.9286
# Mean MAE : 0.7289
# Mean FCP : 0.6482
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9358
# MAE:  0.7206
# FCP:  0.6482
# ------------
# Fold 2
# RMSE: 0.9261
# MAE:  0.7157
# FCP:  0.6508
# ------------
# Fold 3
# RMSE: 0.9358
# MAE:  0.7256
# FCP:  0.6366
# ------------
# Fold 4
# RMSE: 0.9437
# MAE:  0.7299
# FCP:  0.6420
# ------------
# Fold 5
# RMSE: 0.9276
# MAE:  0.7195
# FCP:  0.6409
# ------------
# ------------
# Mean RMSE: 0.9338
# Mean MAE : 0.7223
# Mean FCP : 0.6437
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9580
# MAE:  0.7403
# FCP:  0.6299
# ------------
# Fold 2
# RMSE: 0.9617
# MAE:  0.7386
# FCP:  0.6288
# ------------
# Fold 3
# RMSE: 0.9723
# MAE:  0.7465
# FCP:  0.6321
# ------------
# Fold 4
# RMSE: 0.9588
# MAE:  0.7373
# FCP:  0.6334
# ------------
# Fold 5
# RMSE: 0.9722
# MAE:  0.7486
# FCP:  0.6251
# ------------
# ------------
# Mean RMSE: 0.9646
# Mean MAE : 0.7423
# Mean FCP : 0.6299
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.0294
# MAE:  0.8056
# FCP:  0.6162
# ------------
# Fold 2
# RMSE: 1.0228
# MAE:  0.7984
# FCP:  0.6167
# ------------
# Fold 3
# RMSE: 1.0278
# MAE:  0.8024
# FCP:  0.6171
# ------------
# Fold 4
# RMSE: 1.0227
# MAE:  0.8021
# FCP:  0.6191
# ------------
# Fold 5
# RMSE: 1.0138
# MAE:  0.7908
# FCP:  0.6204
# ------------
# ------------
# Mean RMSE: 1.0233
# Mean MAE : 0.7999
# Mean FCP : 0.6179
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.0919
# MAE:  0.8780
# FCP:  0.6132
# ------------
# Fold 2
# RMSE: 1.0920
# MAE:  0.8767
# FCP:  0.6160
# ------------
# Fold 3
# RMSE: 1.1095
# MAE:  0.8947
# FCP:  0.6004
# ------------
# Fold 4
# RMSE: 1.1104
# MAE:  0.8956
# FCP:  0.6028
# ------------
# Fold 5
# RMSE: 1.1094
# MAE:  0.8933
# FCP:  0.6017
# ------------
# ------------
# Mean RMSE: 1.1026
# Mean MAE : 0.8877
# Mean FCP : 0.6068
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.3237
# MAE:  1.1481
# FCP:  0.6294
# ------------
# Fold 2
# RMSE: 1.3352
# MAE:  1.1544
# FCP:  0.6275
# ------------
# Fold 3
# RMSE: 1.3314
# MAE:  1.1525
# FCP:  0.6230
# ------------
# Fold 4
# RMSE: 1.3346
# MAE:  1.1571
# FCP:  0.6295
# ------------
# Fold 5
# RMSE: 1.3348
# MAE:  1.1552
# FCP:  0.6262
# ------------
# ------------
# Mean RMSE: 1.3319
# Mean MAE : 1.1535
# Mean FCP : 0.6271
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.0334
# MAE:  0.8435
# FCP:  0.6318
# ------------
# Fold 2
# RMSE: 1.0252
# MAE:  0.8405
# FCP:  0.6330
# ------------
# Fold 3
# RMSE: 1.0271
# MAE:  0.8411
# FCP:  0.6354
# ------------
# Fold 4
# RMSE: 1.0302
# MAE:  0.8428
# FCP:  0.6313
# ------------
# Fold 5
# RMSE: 1.0303
# MAE:  0.8457
# FCP:  0.6292
# ------------
# ------------
# Mean RMSE: 1.0293
# Mean MAE : 0.8427
# Mean FCP : 0.6321
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9318
# MAE:  0.7327
# FCP:  0.6506
# ------------
# Fold 2
# RMSE: 0.9255
# MAE:  0.7271
# FCP:  0.6481
# ------------
# Fold 3
# RMSE: 0.9291
# MAE:  0.7305
# FCP:  0.6418
# ------------
# Fold 4
# RMSE: 0.9221
# MAE:  0.7215
# FCP:  0.6593
# ------------
# Fold 5
# RMSE: 0.9266
# MAE:  0.7289
# FCP:  0.6587
# ------------
# ------------
# Mean RMSE: 0.9270
# Mean MAE : 0.7282
# Mean FCP : 0.6517
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9266
# MAE:  0.7198
# FCP:  0.6449
# ------------
# Fold 2
# RMSE: 0.9281
# MAE:  0.7186
# FCP:  0.6472
# ------------
# Fold 3
# RMSE: 0.9250
# MAE:  0.7158
# FCP:  0.6500
# ------------
# Fold 4
# RMSE: 0.9325
# MAE:  0.7220
# FCP:  0.6460
# ------------
# Fold 5
# RMSE: 0.9375
# MAE:  0.7244
# FCP:  0.6450
# ------------
# ------------
# Mean RMSE: 0.9299
# Mean MAE : 0.7201
# Mean FCP : 0.6466
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9633
# MAE:  0.7382
# FCP:  0.6330
# ------------
# Fold 2
# RMSE: 0.9538
# MAE:  0.7328
# FCP:  0.6376
# ------------
# Fold 3
# RMSE: 0.9601
# MAE:  0.7366
# FCP:  0.6371
# ------------
# Fold 4
# RMSE: 0.9729
# MAE:  0.7476
# FCP:  0.6310
# ------------
# Fold 5
# RMSE: 0.9674
# MAE:  0.7451
# FCP:  0.6296
# ------------
# ------------
# Mean RMSE: 0.9635
# Mean MAE : 0.7401
# Mean FCP : 0.6337
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.0069
# MAE:  0.7675
# FCP:  0.6251
# ------------
# Fold 2
# RMSE: 1.0130
# MAE:  0.7729
# FCP:  0.6230
# ------------
# Fold 3
# RMSE: 1.0017
# MAE:  0.7634
# FCP:  0.6217
# ------------
# Fold 4
# RMSE: 1.0186
# MAE:  0.7752
# FCP:  0.6152
# ------------
# Fold 5
# RMSE: 1.0042
# MAE:  0.7658
# FCP:  0.6248
# ------------
# ------------
# Mean RMSE: 1.0089
# Mean MAE : 0.7690
# Mean FCP : 0.6220
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.0485
# MAE:  0.7924
# FCP:  0.6163
# ------------
# Fold 2
# RMSE: 1.0322
# MAE:  0.7794
# FCP:  0.6230
# ------------
# Fold 3
# RMSE: 1.0279
# MAE:  0.7745
# FCP:  0.6213
# ------------
# Fold 4
# RMSE: 1.0309
# MAE:  0.7807
# FCP:  0.6241
# ------------
# Fold 5
# RMSE: 1.0432
# MAE:  0.7892
# FCP:  0.6140
# ------------
# ------------
# Mean RMSE: 1.0365
# Mean MAE : 0.7833
# Mean FCP : 0.6197
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.3298
# MAE:  1.1516
# FCP:  0.6298
# ------------
# Fold 2
# RMSE: 1.3321
# MAE:  1.1519
# FCP:  0.6271
# ------------
# Fold 3
# RMSE: 1.3364
# MAE:  1.1573
# FCP:  0.6237
# ------------
# Fold 4
# RMSE: 1.3349
# MAE:  1.1548
# FCP:  0.6193
# ------------
# Fold 5
# RMSE: 1.3249
# MAE:  1.1492
# FCP:  0.6304
# ------------
# ------------
# Mean RMSE: 1.3316
# Mean MAE : 1.1529
# Mean FCP : 0.6261
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.0281
# MAE:  0.8390
# FCP:  0.6361
# ------------
# Fold 2
# RMSE: 1.0310
# MAE:  0.8451
# FCP:  0.6287
# ------------
# Fold 3
# RMSE: 1.0272
# MAE:  0.8396
# FCP:  0.6340
# ------------
# Fold 4
# RMSE: 1.0367
# MAE:  0.8499
# FCP:  0.6331
# ------------
# Fold 5
# RMSE: 1.0316
# MAE:  0.8469
# FCP:  0.6308
# ------------
# ------------
# Mean RMSE: 1.0309
# Mean MAE : 0.8441
# Mean FCP : 0.6325
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9182
# MAE:  0.7226
# FCP:  0.6438
# ------------
# Fold 2
# RMSE: 0.9260
# MAE:  0.7269
# FCP:  0.6494
# ------------
# Fold 3
# RMSE: 0.9383
# MAE:  0.7362
# FCP:  0.6470
# ------------
# Fold 4
# RMSE: 0.9352
# MAE:  0.7345
# FCP:  0.6458
# ------------
# Fold 5
# RMSE: 0.9222
# MAE:  0.7242
# FCP:  0.6551
# ------------
# ------------
# Mean RMSE: 0.9280
# Mean MAE : 0.7289
# Mean FCP : 0.6482
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9250
# MAE:  0.7142
# FCP:  0.6451
# ------------
# Fold 2
# RMSE: 0.9210
# MAE:  0.7163
# FCP:  0.6576
# ------------
# Fold 3
# RMSE: 0.9252
# MAE:  0.7182
# FCP:  0.6546
# ------------
# Fold 4
# RMSE: 0.9305
# MAE:  0.7222
# FCP:  0.6479
# ------------
# Fold 5
# RMSE: 0.9382
# MAE:  0.7275
# FCP:  0.6492
# ------------
# ------------
# Mean RMSE: 0.9280
# Mean MAE : 0.7197
# Mean FCP : 0.6509
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9650
# MAE:  0.7402
# FCP:  0.6303
# ------------
# Fold 2
# RMSE: 0.9542
# MAE:  0.7318
# FCP:  0.6350
# ------------
# Fold 3
# RMSE: 0.9661
# MAE:  0.7407
# FCP:  0.6399
# ------------
# Fold 4
# RMSE: 0.9574
# MAE:  0.7353
# FCP:  0.6389
# ------------
# Fold 5
# RMSE: 0.9571
# MAE:  0.7358
# FCP:  0.6400
# ------------
# ------------
# Mean RMSE: 0.9600
# Mean MAE : 0.7368
# Mean FCP : 0.6368
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.0354
# MAE:  0.7838
# FCP:  0.6255
# ------------
# Fold 2
# RMSE: 1.0247
# MAE:  0.7721
# FCP:  0.6362
# ------------
# Fold 3
# RMSE: 1.0327
# MAE:  0.7797
# FCP:  0.6307
# ------------
# Fold 4
# RMSE: 1.0384
# MAE:  0.7882
# FCP:  0.6146
# ------------
# Fold 5
# RMSE: 1.0240
# MAE:  0.7751
# FCP:  0.6238
# ------------
# ------------
# Mean RMSE: 1.0310
# Mean MAE : 0.7798
# Mean FCP : 0.6261
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.1413
# MAE:  0.8634
# FCP:  0.6161
# ------------
# Fold 2
# RMSE: 1.1575
# MAE:  0.8739
# FCP:  0.6102
# ------------
# Fold 3
# RMSE: 1.1395
# MAE:  0.8663
# FCP:  0.6188
# ------------
# Fold 4
# RMSE: 1.1535
# MAE:  0.8747
# FCP:  0.6166
# ------------
# Fold 5
# RMSE: 1.1457
# MAE:  0.8727
# FCP:  0.6220
# ------------
# ------------
# Mean RMSE: 1.1475
# Mean MAE : 0.8702
# Mean FCP : 0.6167
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.3362
# MAE:  1.1596
# FCP:  0.6315
# ------------
# Fold 2
# RMSE: 1.3324
# MAE:  1.1515
# FCP:  0.6253
# ------------
# Fold 3
# RMSE: 1.3299
# MAE:  1.1513
# FCP:  0.6244
# ------------
# Fold 4
# RMSE: 1.3281
# MAE:  1.1513
# FCP:  0.6263
# ------------
# Fold 5
# RMSE: 1.3297
# MAE:  1.1506
# FCP:  0.6228
# ------------
# ------------
# Mean RMSE: 1.3313
# Mean MAE : 1.1529
# Mean FCP : 0.6260
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.0353
# MAE:  0.8469
# FCP:  0.6314
# ------------
# Fold 2
# RMSE: 1.0232
# MAE:  0.8365
# FCP:  0.6321
# ------------
# Fold 3
# RMSE: 1.0289
# MAE:  0.8426
# FCP:  0.6246
# ------------
# Fold 4
# RMSE: 1.0337
# MAE:  0.8497
# FCP:  0.6315
# ------------
# Fold 5
# RMSE: 1.0291
# MAE:  0.8421
# FCP:  0.6300
# ------------
# ------------
# Mean RMSE: 1.0300
# Mean MAE : 0.8436
# Mean FCP : 0.6299
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9299
# MAE:  0.7286
# FCP:  0.6503
# ------------
# Fold 2
# RMSE: 0.9254
# MAE:  0.7282
# FCP:  0.6515
# ------------
# Fold 3
# RMSE: 0.9235
# MAE:  0.7239
# FCP:  0.6498
# ------------
# Fold 4
# RMSE: 0.9286
# MAE:  0.7307
# FCP:  0.6526
# ------------
# Fold 5
# RMSE: 0.9249
# MAE:  0.7273
# FCP:  0.6569
# ------------
# ------------
# Mean RMSE: 0.9264
# Mean MAE : 0.7277
# Mean FCP : 0.6522
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9223
# MAE:  0.7163
# FCP:  0.6605
# ------------
# Fold 2
# RMSE: 0.9279
# MAE:  0.7170
# FCP:  0.6481
# ------------
# Fold 3
# RMSE: 0.9282
# MAE:  0.7213
# FCP:  0.6411
# ------------
# Fold 4
# RMSE: 0.9291
# MAE:  0.7195
# FCP:  0.6480
# ------------
# Fold 5
# RMSE: 0.9311
# MAE:  0.7236
# FCP:  0.6524
# ------------
# ------------
# Mean RMSE: 0.9277
# Mean MAE : 0.7195
# Mean FCP : 0.6500
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9590
# MAE:  0.7345
# FCP:  0.6346
# ------------
# Fold 2
# RMSE: 0.9510
# MAE:  0.7322
# FCP:  0.6390
# ------------
# Fold 3
# RMSE: 0.9490
# MAE:  0.7268
# FCP:  0.6391
# ------------
# Fold 4
# RMSE: 0.9509
# MAE:  0.7318
# FCP:  0.6378
# ------------
# Fold 5
# RMSE: 0.9545
# MAE:  0.7329
# FCP:  0.6390
# ------------
# ------------
# Mean RMSE: 0.9529
# Mean MAE : 0.7316
# Mean FCP : 0.6379
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.0690
# MAE:  0.8097
# FCP:  0.6226
# ------------
# Fold 2
# RMSE: 1.0499
# MAE:  0.7875
# FCP:  0.6360
# ------------
# Fold 3
# RMSE: 1.0820
# MAE:  0.8138
# FCP:  0.6254
# ------------
# Fold 4
# RMSE: 1.0575
# MAE:  0.8016
# FCP:  0.6220
# ------------
# Fold 5
# RMSE: 1.0571
# MAE:  0.7998
# FCP:  0.6231
# ------------
# ------------
# Mean RMSE: 1.0631
# Mean MAE : 0.8025
# Mean FCP : 0.6258
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.2629
# MAE:  0.9720
# FCP:  0.5917
# ------------
# Fold 2
# RMSE: 1.2642
# MAE:  0.9799
# FCP:  0.6047
# ------------
# Fold 3
# RMSE: 1.2825
# MAE:  0.9876
# FCP:  0.5991
# ------------
# Fold 4
# RMSE: 1.2808
# MAE:  0.9860
# FCP:  0.5826
# ------------
# Fold 5
# RMSE: 1.2593
# MAE:  0.9709
# FCP:  0.5874
# ------------
# ------------
# Mean RMSE: 1.2699
# Mean MAE : 0.9793
# Mean FCP : 0.5931
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.3398
# MAE:  1.1628
# FCP:  0.6293
# ------------
# Fold 2
# RMSE: 1.3227
# MAE:  1.1451
# FCP:  0.6242
# ------------
# Fold 3
# RMSE: 1.3306
# MAE:  1.1529
# FCP:  0.6341
# ------------
# Fold 4
# RMSE: 1.3258
# MAE:  1.1478
# FCP:  0.6308
# ------------
# Fold 5
# RMSE: 1.3391
# MAE:  1.1574
# FCP:  0.6295
# ------------
# ------------
# Mean RMSE: 1.3316
# Mean MAE : 1.1532
# Mean FCP : 0.6296
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.0275
# MAE:  0.8418
# FCP:  0.6311
# ------------
# Fold 2
# RMSE: 1.0302
# MAE:  0.8428
# FCP:  0.6322
# ------------
# Fold 3
# RMSE: 1.0323
# MAE:  0.8441
# FCP:  0.6242
# ------------
# Fold 4
# RMSE: 1.0299
# MAE:  0.8438
# FCP:  0.6289
# ------------
# Fold 5
# RMSE: 1.0308
# MAE:  0.8442
# FCP:  0.6318
# ------------
# ------------
# Mean RMSE: 1.0301
# Mean MAE : 0.8434
# Mean FCP : 0.6297
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
# ------------
# Fold 1
# RMSE: 0.9209
# MAE:  0.7225
# FCP:  0.6538
# ------------
# Fold 2
# RMSE: 0.9271
# MAE:  0.7301
# FCP:  0.6578
# ------------
# Fold 3
# RMSE: 0.9344
# MAE:  0.7336
# FCP:  0.6533
# ------------
# Fold 4
# RMSE: 0.9279
# MAE:  0.7282
# FCP:  0.6445
# ------------
# Fold 5
# RMSE: 0.9303
# MAE:  0.7318
# FCP:  0.6535
# ------------
# ------------
# Mean RMSE: 0.9281
# Mean MAE : 0.7292
# Mean FCP : 0.6526
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9331
# MAE:  0.7229
# FCP:  0.6486
# ------------
# Fold 2
# RMSE: 0.9142
# MAE:  0.7094
# FCP:  0.6479
# ------------
# Fold 3
# RMSE: 0.9239
# MAE:  0.7154
# FCP:  0.6498
# ------------
# Fold 4
# RMSE: 0.9336
# MAE:  0.7237
# FCP:  0.6551
# ------------
# Fold 5
# RMSE: 0.9307
# MAE:  0.7223
# FCP:  0.6500
# ------------
# ------------
# Mean RMSE: 0.9271
# Mean MAE : 0.7187
# Mean FCP : 0.6503
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 0.9570
# MAE:  0.7316
# FCP:  0.6477
# ------------
# Fold 2
# RMSE: 0.9481
# MAE:  0.7272
# FCP:  0.6346
# ------------
# Fold 3
# RMSE: 0.9536
# MAE:  0.7286
# FCP:  0.6359
# ------------
# Fold 4
# RMSE: 0.9499
# MAE:  0.7278
# FCP:  0.6477
# ------------
# Fold 5
# RMSE: 0.9405
# MAE:  0.7228
# FCP:  0.6443
# ------------
# ------------
# Mean RMSE: 0.9498
# Mean MAE : 0.7276
# Mean FCP : 0.6420
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.0867
# MAE:  0.8218
# FCP:  0.6337
# ------------
# Fold 2
# RMSE: 1.0965
# MAE:  0.8277
# FCP:  0.6212
# ------------
# Fold 3
# RMSE: 1.0852
# MAE:  0.8205
# FCP:  0.6300
# ------------
# Fold 4
# RMSE: 1.0758
# MAE:  0.8146
# FCP:  0.6296
# ------------
# Fold 5
# RMSE: 1.0884
# MAE:  0.8251
# FCP:  0.6243
# ------------
# ------------
# Mean RMSE: 1.0865
# Mean MAE : 0.8220
# Mean FCP : 0.6277
# ------------
# ------------
# Evaluating RMSE, MAE, FCP of algorithm NMF.
#
# ------------
# Fold 1
# RMSE: 1.3646
# MAE:  1.0645
# FCP:  0.5643
# ------------
# Fold 2
# RMSE: 1.3428
# MAE:  1.0469
# FCP:  0.5719
# ------------
# Fold 3
# RMSE: 1.3387
# MAE:  1.0473
# FCP:  0.5710
# ------------
# Fold 4
# RMSE: 1.3566
# MAE:  1.0625
# FCP:  0.5592
# ------------
# Fold 5
# RMSE: 1.3537
# MAE:  1.0564
# FCP:  0.5675
# ------------
# ------------
# Mean RMSE: 1.3513
# Mean MAE : 1.0555
# Mean FCP : 0.5668
# ------------
# ------------

# %%
for l in res_tune:
    s = ""
    for j in res_tune[l]:
        s+=str(sum(res_tune[l][j]['rmse'])/len(res_tune[l][j]['rmse']))+"     "
    s+='\n'
    print(s)
import pickle
pickle.dump(res_tune,open('nmf_factors_regularization.dat','wb'))
# Out:
# 1.33094550153     1.03073976924     0.933513895509     0.936984081979     0.972764730644     1.2084530481     1.58497853777
#
# 1.33174209846     1.03098731304     0.928552447119     0.933780704962     0.964605050968     1.02330101025     1.10264820325
#
# 1.33194068226     1.02926498715     0.927030253544     0.929921960498     0.963501921963     1.00885815653     1.03654752207
#
# 1.33162438202     1.03091925264     0.927966745509     0.927999344431     0.959969985975     1.03102500082     1.14750186888
#
# 1.33126717283     1.03003685056     0.926441966477     0.927709805823     0.952881942485     1.06309849281     1.26994720907
#
# 1.33157720247     1.03012478477     0.928117568624     0.927092232732     0.949809936325     1.0865288731     1.35126139677
